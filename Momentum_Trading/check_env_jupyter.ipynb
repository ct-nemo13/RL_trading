# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Dec 27 18:11:57 2023

@author: ritwi
"""
import gymnasium as gym
import time
import math
import matplotlib.pyplot as plt


'Registering the Gym Environment'
gym.register(id='SingleStockLongOnly', entry_point='main_Env:SingleStockLongOnly')


test_agent_id = 'random_agent'
episodes = 3


'Calling the Environment'
env = gym.make('SingleStockLongOnly',
               env_config={'mode':'test',
                           'test_agent_id': test_agent_id,
                           'data_dir':'data_dir/train_data',
                           'episode_length_in_steps': 5,                      
                           'look_back_window': 3,
                           'initial_fund_in_money': 500000,
                           'fee_percentage': 0.1,
                           'max_fee': 40,
                           'lowest_acceptabl_net_worth': 0.75,
                           'position_per_action_value': 0.5}
               )    

print('\nObservation Sample\n', env.observation_space)
print('\nObservation Sample\n', env.observation_space.sample())
print('\nAction Sample\n', env.action_space.sample())


'Play an Eplisode with a Random Agent'
reward_list = []
for episode in range(episodes):
    
    'Starting countdown to measure the time taken for one episode'
    start = time.time()
    done = False
    obs = env.reset()
    print('\nObservation after Reset:', obs)
    total_reward = 0
    score = 0
    while not done:
        'Taking an random action'
        random_action = env.action_space.sample()
        print('\nAction taken by the agent:',random_action)
        
        'Getting the observation, reward and done status from the environment'
        obs, reward, done, info = env.step(random_action)
        print('\nInfo:',info)
        print('\nReward at the step:', reward)
        print('\nObservation at the step:', obs)
        
        total_reward += reward
    
    reward_list.append((math.exp(total_reward)-1) * 100)
    end = time.time()
    print(f"Time taken for the episode: {(end-start)*10**3:.03f}ms")
    
    
'Plotting a Reward histogram'
plt.hist(reward_list, bins=30, color='blue', edgecolor='black')
'Adding labels and title'
plt.xlabel('% Reward')
plt.ylabel('Frequency')
plt.title('Reward Histogram')

'Save the histogram plot.'
file_path = 'test_logs/' + test_agent_id + '/Reward_in_Percentage_Histogram.jpeg'


plt.savefig(file_path, dpi=500)

'Display the plot'
plt.show()
# Out:
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\envs\registration.py:694: UserWarning:
#
# WARN: Overriding environment SingleStockLongOnly already in registry.
#
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:168: DeprecationWarning:
#
# WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:181: DeprecationWarning:
#
# WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:189: UserWarning:
#
# WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:213: DeprecationWarning:
#
# WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
# The "test_logs" directory already exists.
#
# List of Stocks:
#  ['APOLLOTYRE', 'AUROPHARMA', 'AXISBANK', 'BAJFINANCE', 'BHARATFORG', 'BHARTIARTL', 'CANBK', 'DIVISLAB', 'DLF', 'DRREDDY', 'GLENMARK', 'HCLTECH', 'HEROMOTOCO', 'HINDALCO', 'ICICIBANK', 'INFY', 'JSWSTEEL', 'JUBLFOOD', 'MARUTI', 'RELIANCE', 'SBIN', 'TATAMOTORS', 'TATASTEEL', 'TCS', 'WIPRO']
#
# All Observation Parameters: ['open', 'high', 'low', 'close', 'volume', 'money_n', 'stock_n', 'net_worth_n', 'fund_status', 'reward']
#
# Observation Sample
#  Box(-inf, inf, (3, 10), float64)
#
# Observation Sample
#  [[ 4.47559031e-01 -2.27804023e-03  1.40289119e+00 -5.15458787e-02
#    7.81508093e-01  7.95223990e-01 -6.82907065e-01 -1.46108423e+00
#    1.74278620e+00 -8.81973814e-01]
#  [ 2.54447273e+00 -2.61755559e+00  8.90808754e-01 -1.11561670e+00
#   -4.42537680e-02  7.22880290e-01  1.60480825e+00 -1.23043638e+00
#   -6.62077032e-01  5.72828386e-01]
#  [ 2.03290061e-01 -4.89834230e-01  2.78072106e-01 -1.92507424e+00
#    2.75415242e-01  2.96676841e-01  5.97181578e-01 -4.86367006e-01
#   -1.37281152e+00  1.04510815e+00]]
#
# Action Sample
#  4
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: DLF
#
# The dataframe containing historical data of the selected stock:
#                         open    high     low   close  volume
# date
# 2023-06-23 13:25:00  478.75  479.70  478.55  479.20   16090
# 2023-06-23 13:30:00  479.20  479.30  478.80  479.15   10054
# 2023-06-23 13:35:00  479.15  479.85  479.00  479.65    8538
# 2023-06-23 13:40:00  479.65  480.75  479.40  480.10   16430
# 2023-06-23 13:45:00  480.10  481.20  480.10  481.20   13754
# ...                     ...     ...     ...     ...     ...
# 2023-08-30 12:05:00  501.35  501.90  501.25  501.90   78308
# 2023-08-30 12:10:00  501.90  501.95  501.00  501.00   39195
# 2023-08-30 12:15:00  501.00  501.25  500.50  500.50   20513
# 2023-08-30 12:20:00  500.50  500.50  499.80  500.05   29556
# 2023-08-30 12:25:00  500.10  501.00  499.80  500.80   28240
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-06-27 09:50:00
#
# The start time at the reset: 2023-06-27 09:30:00
#
# Int index of the df from where observation starts at reset: 101
#
# Int index of the df where observation end at reset: 103
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499818.2
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499939.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499765.4
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[4.82000e+02 4.82450e+02 4.79000e+02 4.81950e+02 2.05278e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [4.83200e+02 4.83500e+02 4.81650e+02 4.83500e+02 1.23000e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [4.83400e+02 4.83800e+02 4.82750e+02 4.83400e+02 7.48520e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Done Status after the reset: False
# The test episode count: 1
#
# The reset is completed
#
# Observation after Reset: [[4.82000e+02 4.82450e+02 4.79000e+02 4.81950e+02 2.05278e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [4.83200e+02 4.83500e+02 4.81650e+02 4.83500e+02 1.23000e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [4.83400e+02 4.83800e+02 4.82750e+02 4.83400e+02 7.48520e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 3
#
# The action, applied to the env by the agent: 3
#
# The actual action after scalling: 1
#
# The execution price: 483.630745790003
#
# Buy Action
#
#
# Target position to buy in money: 249980.0
#
# Actual stock quantity bought: 516.0
#
# The actual money spent to purchase stock: 249553.46482764155
#
# The total fee to be paid 40
# Reward at the step: 0.0006620511404885523
# The appended action list: [np.int64(1)]
#
# The Normalized Money Reserve: 0.5008130703447169
#
# The Normalized Stock Reserve: 0.4998492
#
# The Normalized Net Worth: 1.000662270344717
#
# The Money Reserve: 250406.53517235845
#
# The Effective Money Reserve: 249976.19999999998
#
# The Stock Reserve in Numbers: 516.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-27 09:35:00 False
# The updated observation at the end of the step:
#  [[4.83200000e+02 4.83500000e+02 4.81650000e+02 4.83500000e+02
#   1.23000000e+05 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [4.83400000e+02 4.83800000e+02 4.82750000e+02 4.83400000e+02
#   7.48520000e+04 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [4.84200000e+02 4.84450000e+02 4.83250000e+02 4.84350000e+02
#   7.10440000e+04 5.00813070e-01 4.99849200e-01 1.00066227e+00
#   2.00000000e+00 6.62051140e-04]]
# {'Time': Timestamp('2023-06-27 09:35:00')}
#
# Info: {'Time': Timestamp('2023-06-27 09:35:00')}
#
# Reward at the step: 0.0006620511404885523
#
# Observation at the step: [[4.83200000e+02 4.83500000e+02 4.81650000e+02 4.83500000e+02
#   1.23000000e+05 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [4.83400000e+02 4.83800000e+02 4.82750000e+02 4.83400000e+02
#   7.48520000e+04 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [4.84200000e+02 4.84450000e+02 4.83250000e+02 4.84350000e+02
#   7.10440000e+04 5.00813070e-01 4.99849200e-01 1.00066227e+00
#   2.00000000e+00 6.62051140e-04]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 484.3038552287474
#
# Hold Action
#
# Reward at the step: 0.00025779601508706736
# The appended action list: [np.int64(1), np.int64(0)]
#
# The Normalized Money Reserve: 0.5008130703447169
#
# The Normalized Stock Reserve: 0.5001072
#
# The Normalized Net Worth: 1.0009202703447169
#
# The Money Reserve: 250406.53517235845
#
# The Effective Money Reserve: 249981.0
#
# The Stock Reserve in Numbers: 516.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-27 09:40:00 False
# The updated observation at the end of the step:
#  [[4.83400000e+02 4.83800000e+02 4.82750000e+02 4.83400000e+02
#   7.48520000e+04 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [4.84200000e+02 4.84450000e+02 4.83250000e+02 4.84350000e+02
#   7.10440000e+04 5.00813070e-01 4.99849200e-01 1.00066227e+00
#   2.00000000e+00 6.62051140e-04]
#  [4.84850000e+02 4.85400000e+02 4.83750000e+02 4.84600000e+02
#   1.04704000e+05 5.00813070e-01 5.00107200e-01 1.00092027e+00
#   2.00000000e+00 2.57796015e-04]]
# {'Time': Timestamp('2023-06-27 09:40:00')}
#
# Info: {'Time': Timestamp('2023-06-27 09:40:00')}
#
# Reward at the step: 0.00025779601508706736
#
# Observation at the step: [[4.83400000e+02 4.83800000e+02 4.82750000e+02 4.83400000e+02
#   7.48520000e+04 1.00000000e+00 0.00000000e+00 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [4.84200000e+02 4.84450000e+02 4.83250000e+02 4.84350000e+02
#   7.10440000e+04 5.00813070e-01 4.99849200e-01 1.00066227e+00
#   2.00000000e+00 6.62051140e-04]
#  [4.84850000e+02 4.85400000e+02 4.83750000e+02 4.84600000e+02
#   1.04704000e+05 5.00813070e-01 5.00107200e-01 1.00092027e+00
#   2.00000000e+00 2.57796015e-04]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# The execution price: 484.79167071707235
#
# Sell Action
#
#
# Stock Reserve 516.0
#
# Actual stock quantity to be sold 258
#
# Actual money earned in the stock selling: 125076.25104500467
#
# The total fee to be paid 40
# Reward at the step: -0.00016156229149926559
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1)]
#
# The Normalized Money Reserve: 0.7508855724347262
#
# The Normalized Stock Reserve: 0.249873
#
# The Normalized Net Worth: 1.000758572434726
#
# The Money Reserve: 375442.7862173631
#
# The Effective Money Reserve: 375059.6
#
# The Stock Reserve in Numbers: 258.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-27 09:45:00 False
# The updated observation at the end of the step:
#  [[ 4.84200000e+02  4.84450000e+02  4.83250000e+02  4.84350000e+02
#    7.10440000e+04  5.00813070e-01  4.99849200e-01  1.00066227e+00
#    2.00000000e+00  6.62051140e-04]
#  [ 4.84850000e+02  4.85400000e+02  4.83750000e+02  4.84600000e+02
#    1.04704000e+05  5.00813070e-01  5.00107200e-01  1.00092027e+00
#    2.00000000e+00  2.57796015e-04]
#  [ 4.84050000e+02  4.85200000e+02  4.84000000e+02  4.84250000e+02
#    6.63510000e+04  7.50885572e-01  2.49873000e-01  1.00075857e+00
#    2.00000000e+00 -1.61562291e-04]]
# {'Time': Timestamp('2023-06-27 09:45:00')}
#
# Info: {'Time': Timestamp('2023-06-27 09:45:00')}
#
# Reward at the step: -0.00016156229149926559
#
# Observation at the step: [[ 4.84200000e+02  4.84450000e+02  4.83250000e+02  4.84350000e+02
#    7.10440000e+04  5.00813070e-01  4.99849200e-01  1.00066227e+00
#    2.00000000e+00  6.62051140e-04]
#  [ 4.84850000e+02  4.85400000e+02  4.83750000e+02  4.84600000e+02
#    1.04704000e+05  5.00813070e-01  5.00107200e-01  1.00092027e+00
#    2.00000000e+00  2.57796015e-04]
#  [ 4.84050000e+02  4.85200000e+02  4.84000000e+02  4.84250000e+02
#    6.63510000e+04  7.50885572e-01  2.49873000e-01  1.00075857e+00
#    2.00000000e+00 -1.61562291e-04]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# The execution price: 483.42296825689124
#
# Sell Action
#
#
# Stock Reserve 258.0
#
# Actual stock quantity to be sold 129
#
# Actual money earned in the stock selling: 62361.56290513897
#
# The total fee to be paid 40
# Reward at the step: -0.00016426308494920533
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1), np.int64(-1)]
#
# The Normalized Money Reserve: 0.875528698245004
#
# The Normalized Stock Reserve: 0.1250655
#
# The Normalized Net Worth: 1.000594198245004
#
# The Money Reserve: 437764.349122502
#
# The Effective Money Reserve: 437244.5
#
# The Stock Reserve in Numbers: 129.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-27 09:50:00 False
# The updated observation at the end of the step:
#  [[ 4.84850000e+02  4.85400000e+02  4.83750000e+02  4.84600000e+02
#    1.04704000e+05  5.00813070e-01  5.00107200e-01  1.00092027e+00
#    2.00000000e+00  2.57796015e-04]
#  [ 4.84050000e+02  4.85200000e+02  4.84000000e+02  4.84250000e+02
#    6.63510000e+04  7.50885572e-01  2.49873000e-01  1.00075857e+00
#    2.00000000e+00 -1.61562291e-04]
#  [ 4.84850000e+02  4.84750000e+02  4.83250000e+02  4.84750000e+02
#    5.17030000e+04  8.75528698e-01  1.25065500e-01  1.00059420e+00
#    2.00000000e+00 -1.64263085e-04]]
# {'Time': Timestamp('2023-06-27 09:50:00')}
#
# Info: {'Time': Timestamp('2023-06-27 09:50:00')}
#
# Reward at the step: -0.00016426308494920533
#
# Observation at the step: [[ 4.84850000e+02  4.85400000e+02  4.83750000e+02  4.84600000e+02
#    1.04704000e+05  5.00813070e-01  5.00107200e-01  1.00092027e+00
#    2.00000000e+00  2.57796015e-04]
#  [ 4.84050000e+02  4.85200000e+02  4.84000000e+02  4.84250000e+02
#    6.63510000e+04  7.50885572e-01  2.49873000e-01  1.00075857e+00
#    2.00000000e+00 -1.61562291e-04]
#  [ 4.84850000e+02  4.84750000e+02  4.83250000e+02  4.84750000e+02
#    5.17030000e+04  8.75528698e-01  1.25065500e-01  1.00059420e+00
#    2.00000000e+00 -1.64263085e-04]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# The execution price: 485.75904439699866
#
# Sell Action
#
#
# Stock Reserve 129.0
#
# Actual stock quantity to be sold 64
#
# Actual money earned in the stock selling: 31088.578841407914
#
# The total fee to be paid 31.088578841407916
# Reward at the step: 0.0001513791107266272
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1), np.int64(-1), np.int64(-1)]
#
# The net Worth at the end of the episode: 500372.8393850685
#
#  The episode length was: 4
# The Normalized Money Reserve: 0.937643678770137
#
# The Normalized Stock Reserve: 0.063102
#
# The Normalized Net Worth: 1.000745678770137
#
# The Money Reserve: 468821.8393850685
#
# The Effective Money Reserve: 468504.0
#
# The Stock Reserve in Numbers: 65.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-27 09:55:00 True
# The updated observation at the end of the step:
#  [[ 4.84050000e+02  4.85200000e+02  4.84000000e+02  4.84250000e+02
#    6.63510000e+04  7.50885572e-01  2.49873000e-01  1.00075857e+00
#    2.00000000e+00 -1.61562291e-04]
#  [ 4.84850000e+02  4.84750000e+02  4.83250000e+02  4.84750000e+02
#    5.17030000e+04  8.75528698e-01  1.25065500e-01  1.00059420e+00
#    2.00000000e+00 -1.64263085e-04]
#  [ 4.85400000e+02  4.86000000e+02  4.84600000e+02  4.85400000e+02
#    6.57480000e+04  9.37643679e-01  6.31020000e-02  1.00074568e+00
#    2.00000000e+00  1.51379111e-04]]
# {'Time': Timestamp('2023-06-27 09:55:00')}
#
# Info: {'Time': Timestamp('2023-06-27 09:55:00')}
#
# Reward at the step: 0.0001513791107266272
#
# Observation at the step: [[ 4.84050000e+02  4.85200000e+02  4.84000000e+02  4.84250000e+02
#    6.63510000e+04  7.50885572e-01  2.49873000e-01  1.00075857e+00
#    2.00000000e+00 -1.61562291e-04]
#  [ 4.84850000e+02  4.84750000e+02  4.83250000e+02  4.84750000e+02
#    5.17030000e+04  8.75528698e-01  1.25065500e-01  1.00059420e+00
#    2.00000000e+00 -1.64263085e-04]
#  [ 4.85400000e+02  4.86000000e+02  4.84600000e+02  4.85400000e+02
#    6.57480000e+04  9.37643679e-01  6.31020000e-02  1.00074568e+00
#    2.00000000e+00  1.51379111e-04]]
# Time taken for the episode: 1337.673ms
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: RELIANCE
#
# The dataframe containing historical data of the selected stock:
#                          open     high      low    close  volume
# date
# 2023-06-23 12:35:00  2409.45  2410.75  2409.45  2410.40   11545
# 2023-06-23 12:40:00  2410.80  2410.80  2409.20  2410.60   11762
# 2023-06-23 12:45:00  2410.60  2411.60  2409.70  2410.60   19428
# 2023-06-23 12:50:00  2410.60  2410.65  2408.75  2409.50    9801
# 2023-06-23 12:55:00  2409.40  2410.45  2407.30  2409.70   14884
# ...                      ...      ...      ...      ...     ...
# 2023-08-30 12:00:00  2432.80  2433.00  2430.75  2430.80   25227
# 2023-08-30 12:05:00  2430.80  2432.80  2429.95  2431.65   78425
# 2023-08-30 12:10:00  2431.30  2432.00  2430.30  2431.75   15101
# 2023-08-30 12:15:00  2431.75  2432.00  2430.10  2431.90   17467
# 2023-08-30 12:20:00  2431.15  2433.00  2431.10  2432.45   22106
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-08-28 13:10:00
#
# The start time at the reset: 2023-08-28 12:50:00
#
# Int index of the df from where observation starts at reset: 3292
#
# Int index of the df where observation end at reset: 3294
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 497856.9
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499939.89999999997
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499849.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[2.47495e+03 2.47690e+03 2.47360e+03 2.47495e+03 5.08060e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [2.47315e+03 2.47495e+03 2.47235e+03 2.47315e+03 2.48280e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [2.47435e+03 2.47450e+03 2.47205e+03 2.47430e+03 2.78680e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Done Status after the reset: False
# The test episode count: 2
#
# The reset is completed
#
# Observation after Reset: [[2.47495e+03 2.47690e+03 2.47360e+03 2.47495e+03 5.08060e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [2.47315e+03 2.47495e+03 2.47235e+03 2.47315e+03 2.48280e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [2.47435e+03 2.47450e+03 2.47205e+03 2.47430e+03 2.78680e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 3
#
# The action, applied to the env by the agent: 3
#
# The actual action after scalling: 1
#
# The execution price: 2476.7815645973005
#
# Buy Action
#
#
# Target position to buy in money: 249980.0
#
# Actual stock quantity bought: 100.0
#
# The actual money spent to purchase stock: 247678.15645973006
#
# The total fee to be paid 40
# Reward at the step: -5.63145050920435e-05
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1), np.int64(-1), np.int64(-1), np.int64(1)]
#
# The Normalized Money Reserve: 0.5045636870805399
#
# The Normalized Stock Reserve: 0.49538
#
# The Normalized Net Worth: 0.9999436870805398
#
# The Money Reserve: 252281.84354026994
#
# The Effective Money Reserve: 250166.90000000002
#
# The Stock Reserve in Numbers: 100.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-08-28 12:55:00 False
# The updated observation at the end of the step:
#  [[ 2.47315000e+03  2.47495000e+03  2.47235000e+03  2.47315000e+03
#    2.48280000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 2.47435000e+03  2.47450000e+03  2.47205000e+03  2.47430000e+03
#    2.78680000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 2.47690000e+03  2.47690000e+03  2.47420000e+03  2.47690000e+03
#    3.42250000e+04  5.04563687e-01  4.95380000e-01  9.99943687e-01
#    2.00000000e+00 -5.63145051e-05]]
# {'Time': Timestamp('2023-08-28 12:55:00')}
#
# Info: {'Time': Timestamp('2023-08-28 12:55:00')}
#
# Reward at the step: -5.63145050920435e-05
#
# Observation at the step: [[ 2.47315000e+03  2.47495000e+03  2.47235000e+03  2.47315000e+03
#    2.48280000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 2.47435000e+03  2.47450000e+03  2.47205000e+03  2.47430000e+03
#    2.78680000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 2.47690000e+03  2.47690000e+03  2.47420000e+03  2.47690000e+03
#    3.42250000e+04  5.04563687e-01  4.95380000e-01  9.99943687e-01
#    2.00000000e+00 -5.63145051e-05]]
#
# Action taken by the agent: 0
#
# The action, applied to the env by the agent: 0
#
# The actual action after scalling: -2
#
# The execution price: 2476.7659409886805
#
# Sell Action
#
#
# Stock Reserve 100.0
#
# Actual stock quantity to be sold 100
#
# Actual money earned in the stock selling: 247676.59409886805
#
# The total fee to be paid 40
# Reward at the step: -0.00010682352291647914
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1), np.int64(-1), np.int64(-1), np.int64(1), np.int64(-2)]
#
# The Normalized Money Reserve: 0.9998368752782759
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 0.9998368752782759
#
# The Money Reserve: 499918.43763913796
#
# The Effective Money Reserve: 497856.9
#
# The Stock Reserve in Numbers: 0.0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-08-28 13:00:00 False
# The updated observation at the end of the step:
#  [[ 2.47435000e+03  2.47450000e+03  2.47205000e+03  2.47430000e+03
#    2.78680000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 2.47690000e+03  2.47690000e+03  2.47420000e+03  2.47690000e+03
#    3.42250000e+04  5.04563687e-01  4.95380000e-01  9.99943687e-01
#    2.00000000e+00 -5.63145051e-05]
#  [ 2.47445000e+03  2.47690000e+03  2.47505000e+03  2.47505000e+03
#    3.58700000e+04  9.99836875e-01  0.00000000e+00  9.99836875e-01
#    1.00000000e+00 -1.06823523e-04]]
# {'Time': Timestamp('2023-08-28 13:00:00')}
#
# Info: {'Time': Timestamp('2023-08-28 13:00:00')}
#
# Reward at the step: -0.00010682352291647914
#
# Observation at the step: [[ 2.47435000e+03  2.47450000e+03  2.47205000e+03  2.47430000e+03
#    2.78680000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 2.47690000e+03  2.47690000e+03  2.47420000e+03  2.47690000e+03
#    3.42250000e+04  5.04563687e-01  4.95380000e-01  9.99943687e-01
#    2.00000000e+00 -5.63145051e-05]
#  [ 2.47445000e+03  2.47690000e+03  2.47505000e+03  2.47505000e+03
#    3.58700000e+04  9.99836875e-01  0.00000000e+00  9.99836875e-01
#    1.00000000e+00 -1.06823523e-04]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# Stock Holdings 0.0
#
# Action: -1
#
# Fund_Status: 1
#
# Episode is terminating due to wrong Sell Action
#
# Penalty for Wrong Action: -10
#
# The execution price: 2472.1572623033576
#
# Sell Action
#
#
# Stock Reserve 0.0
#
# Actual stock quantity to be sold 0
#
# Actual money earned in the stock selling: 0.0
#
# The total fee to be paid 0.0
# Reward at the step: -10.0
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1), np.int64(-1), np.int64(-1), np.int64(1), np.int64(-2), np.int64(-1)]
#
# The net Worth at the end of the episode: 499918.43763913796
#
#  The episode length was: 2
# The Normalized Money Reserve: 0.9998368752782759
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 0.9998368752782759
#
# The Money Reserve: 499918.43763913796
#
# The Effective Money Reserve: 497495.1
#
# The Stock Reserve in Numbers: 0.0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-08-28 13:05:00 True
# The updated observation at the end of the step:
#  [[ 2.47690000e+03  2.47690000e+03  2.47420000e+03  2.47690000e+03
#    3.42250000e+04  5.04563687e-01  4.95380000e-01  9.99943687e-01
#    2.00000000e+00 -5.63145051e-05]
#  [ 2.47445000e+03  2.47690000e+03  2.47505000e+03  2.47505000e+03
#    3.58700000e+04  9.99836875e-01  0.00000000e+00  9.99836875e-01
#    1.00000000e+00 -1.06823523e-04]
#  [ 2.47235000e+03  2.47510000e+03  2.47115000e+03  2.47290000e+03
#    6.35450000e+04  9.99836875e-01  0.00000000e+00  9.99836875e-01
#    1.00000000e+00 -1.00000000e+01]]
# {'Time': Timestamp('2023-08-28 13:05:00')}
#
# Info: {'Time': Timestamp('2023-08-28 13:05:00')}
#
# Reward at the step: -10.0
#
# Observation at the step: [[ 2.47690000e+03  2.47690000e+03  2.47420000e+03  2.47690000e+03
#    3.42250000e+04  5.04563687e-01  4.95380000e-01  9.99943687e-01
#    2.00000000e+00 -5.63145051e-05]
#  [ 2.47445000e+03  2.47690000e+03  2.47505000e+03  2.47505000e+03
#    3.58700000e+04  9.99836875e-01  0.00000000e+00  9.99836875e-01
#    1.00000000e+00 -1.06823523e-04]
#  [ 2.47235000e+03  2.47510000e+03  2.47115000e+03  2.47290000e+03
#    6.35450000e+04  9.99836875e-01  0.00000000e+00  9.99836875e-01
#    1.00000000e+00 -1.00000000e+01]]
# Time taken for the episode: 1265.650ms
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: ICICIBANK
#
# The dataframe containing historical data of the selected stock:
#                         open    high     low   close  volume
# date
# 2023-06-23 12:55:00  923.65  923.80  922.00  922.45  159645
# 2023-06-23 13:00:00  922.65  922.85  921.70  922.20   58620
# 2023-06-23 13:05:00  922.20  923.00  921.55  922.35   47068
# 2023-06-23 13:10:00  922.45  923.00  922.15  922.75   65708
# 2023-06-23 13:15:00  922.75  924.00  921.90  923.95  109717
# ...                     ...     ...     ...     ...     ...
# 2023-08-30 11:35:00  968.95  969.00  968.50  968.50   82101
# 2023-08-30 11:40:00  968.60  968.80  968.45  968.80  100123
# 2023-08-30 11:45:00  968.85  968.95  968.60  968.60   76359
# 2023-08-30 11:50:00  968.65  969.00  968.40  968.75  155988
# 2023-08-30 11:55:00  968.70  968.75  967.80  967.95  260055
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-08-01 11:55:00
#
# The start time at the reset: 2023-08-01 11:35:00
#
# Int index of the df from where observation starts at reset: 1932
#
# Int index of the df where observation end at reset: 1934
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499547.10000000003
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499497.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499246.5
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[9.9590e+02 9.9710e+02 9.9575e+02 9.9575e+02 6.4560e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [9.9600e+02 9.9700e+02 9.9575e+02 9.9600e+02 9.0920e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [9.9550e+02 9.9650e+02 9.9515e+02 9.9595e+02 9.1972e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]]
#
# Done Status after the reset: False
# The test episode count: 3
#
# The reset is completed
#
# Observation after Reset: [[9.9590e+02 9.9710e+02 9.9575e+02 9.9575e+02 6.4560e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [9.9600e+02 9.9700e+02 9.9575e+02 9.9600e+02 9.0920e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [9.9550e+02 9.9650e+02 9.9515e+02 9.9595e+02 9.1972e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]]
#
# Action taken by the agent: 0
#
# The action, applied to the env by the agent: 0
#
# The actual action after scalling: -2
#
# Stock Holdings 0
#
# Action: -2
#
# Fund_Status: 1
#
# Episode is terminating due to wrong Sell Action
#
# Penalty for Wrong Action: -10
#
# The execution price: 996.5471535405168
#
# Sell Action
#
#
# Stock Reserve 0
#
# Actual stock quantity to be sold 0
#
# Actual money earned in the stock selling: 0.0
#
# The total fee to be paid 0.0
# Reward at the step: -10.0
# The appended action list: [np.int64(1), np.int64(0), np.int64(-1), np.int64(-1), np.int64(-1), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-2)]
#
# The net Worth at the end of the episode: 500000.0
#
#  The episode length was: 0
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000.0
#
# The Effective Money Reserve: 499396.8
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-08-01 11:40:00 True
# The updated observation at the end of the step:
#  [[ 9.9600e+02  9.9700e+02  9.9575e+02  9.9600e+02  9.0920e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 9.9550e+02  9.9650e+02  9.9515e+02  9.9595e+02  9.1972e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 9.9595e+02  9.9680e+02  9.9550e+02  9.9595e+02  6.3042e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00 -1.0000e+01]]
# {'Time': Timestamp('2023-08-01 11:40:00')}
#
# Info: {'Time': Timestamp('2023-08-01 11:40:00')}
#
# Reward at the step: -10.0
#
# Observation at the step: [[ 9.9600e+02  9.9700e+02  9.9575e+02  9.9600e+02  9.0920e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 9.9550e+02  9.9650e+02  9.9515e+02  9.9595e+02  9.1972e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 9.9595e+02  9.9680e+02  9.9550e+02  9.9595e+02  6.3042e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00 -1.0000e+01]]
# Time taken for the episode: 918.094ms
