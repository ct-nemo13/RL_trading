# %%
# !pip install gymnasium==0.29.1
# !pip install matplotlib
# !pip install pandas
# !pip install plotly

# !pip install -U "ray[data,train,tune,serve]"
# !pip install -U "ray[default]"
# !pip install -U "ray[all]"
# Out:
# Requirement already satisfied: gymnasium==0.29.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (2.2.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: matplotlib in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: plotly in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from plotly) (1.27.1)
# Requirement already satisfied: packaging in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: ray[data,serve,train,tune] in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (2.42.1)
# Requirement already satisfied: click>=7.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (8.1.7)
# Requirement already satisfied: filelock in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (3.17.0)
# Requirement already satisfied: jsonschema in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (1.1.0)
# Requirement already satisfied: packaging in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (5.29.3)
# Requirement already satisfied: pyyaml in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (6.0.2)
# Requirement already satisfied: aiosignal in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (1.5.0)
# Requirement already satisfied: requests in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (2.32.3)
# Requirement already satisfied: opencensus in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.11.4)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (1.70.0)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (3.11.10)
# Requirement already satisfied: colorful in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.4.0)
# Requirement already satisfied: smart_open in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (20.29.2)
# Requirement already satisfied: prometheus_client>=0.7.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.21.0)
# Requirement already satisfied: fastapi in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.115.8)
# Requirement already satisfied: uvicorn[standard] in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.34.0)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (2.10.6)
# Requirement already satisfied: watchfiles in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (1.0.4)
# Requirement already satisfied: aiohttp_cors in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.7.0)
# Requirement already satisfied: starlette in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (0.45.3)
# Requirement already satisfied: pandas in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (2.2.3)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (19.0.0)
# Requirement already satisfied: fsspec in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (2025.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[data,serve,train,tune]) (2.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[data,serve,train,tune]) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[data,serve,train,tune]) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[data,serve,train,tune]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[data,serve,train,tune]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[data,serve,train,tune]) (1.18.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[data,serve,train,tune]) (5.0.1)
# Requirement already satisfied: colorama in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from click>=7.0->ray[data,serve,train,tune]) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas->ray[data,serve,train,tune]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas->ray[data,serve,train,tune]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas->ray[data,serve,train,tune]) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[data,serve,train,tune]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[data,serve,train,tune]) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[data,serve,train,tune]) (4.12.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,serve,train,tune]) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[data,serve,train,tune]) (3.10.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from starlette->ray[data,serve,train,tune]) (4.6.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[data,serve,train,tune]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[data,serve,train,tune]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[data,serve,train,tune]) (0.22.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[data,serve,train,tune]) (0.1.3)
# Requirement already satisfied: six~=1.16 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[data,serve,train,tune]) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[data,serve,train,tune]) (2.24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[data,serve,train,tune]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[data,serve,train,tune]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[data,serve,train,tune]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[data,serve,train,tune]) (2025.1.31)
# Requirement already satisfied: wrapt in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from smart_open->ray[data,serve,train,tune]) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "serve"->ray[data,serve,train,tune]) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "serve"->ray[data,serve,train,tune]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "serve"->ray[data,serve,train,tune]) (1.0.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "serve"->ray[data,serve,train,tune]) (15.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from anyio<5,>=3.6.2->starlette->ray[data,serve,train,tune]) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from anyio<5,>=3.6.2->starlette->ray[data,serve,train,tune]) (1.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (1.67.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (2.38.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[data,serve,train,tune]) (0.6.1)
# Requirement already satisfied: ray[default] in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (2.42.1)
# Requirement already satisfied: click>=7.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (8.1.7)
# Requirement already satisfied: filelock in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (3.17.0)
# Requirement already satisfied: jsonschema in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (1.1.0)
# Requirement already satisfied: packaging in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (5.29.3)
# Requirement already satisfied: pyyaml in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (6.0.2)
# Requirement already satisfied: aiosignal in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (1.5.0)
# Requirement already satisfied: requests in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (2.32.3)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (3.11.10)
# Requirement already satisfied: aiohttp_cors in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (0.7.0)
# Requirement already satisfied: colorful in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (1.70.0)
# Requirement already satisfied: opencensus in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (2.10.6)
# Requirement already satisfied: prometheus_client>=0.7.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (0.21.0)
# Requirement already satisfied: smart_open in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[default]) (20.29.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[default]) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[default]) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[default]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[default]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[default]) (1.18.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[default]) (5.0.1)
# Requirement already satisfied: colorama in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from click>=7.0->ray[default]) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default]) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default]) (4.12.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]) (3.10.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[default]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[default]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[default]) (0.22.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[default]) (0.1.3)
# Requirement already satisfied: six~=1.16 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[default]) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[default]) (2.24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[default]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[default]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[default]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[default]) (2025.1.31)
# Requirement already satisfied: wrapt in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from smart_open->ray[default]) (1.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.67.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (2.38.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.6.1)
# Requirement already satisfied: ray[all] in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (2.42.1)
# Requirement already satisfied: click>=7.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (8.1.7)
# Requirement already satisfied: filelock in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (3.17.0)
# Requirement already satisfied: jsonschema in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (1.1.0)
# Requirement already satisfied: packaging in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (5.29.3)
# Requirement already satisfied: pyyaml in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (6.0.2)
# Requirement already satisfied: aiosignal in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (1.2.0)
# Requirement already satisfied: frozenlist in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (1.5.0)
# Requirement already satisfied: requests in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (2.32.3)
# Collecting cupy-cuda12x (from ray[all])
#   Downloading cupy_cuda12x-13.3.0-cp310-cp310-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: grpcio in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (1.70.0)
# Requirement already satisfied: smart_open in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (20.29.2)
# Requirement already satisfied: pandas in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (2.2.3)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (2.10.6)
# Collecting opentelemetry-sdk (from ray[all])
#   Downloading opentelemetry_sdk-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (2.2.3)
# Collecting dm_tree (from ray[all])
#   Downloading dm_tree-0.1.9-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting opentelemetry-exporter-otlp (from ray[all])
#   Downloading opentelemetry_exporter_otlp-1.30.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: uvicorn[standard] in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.34.0)
# Collecting lz4 (from ray[all])
#   Downloading lz4-4.4.3-cp310-cp310-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (2.6.2.2)
# Collecting pyOpenSSL (from ray[all])
#   Downloading pyOpenSSL-25.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: colorful in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.5.6)
# Requirement already satisfied: opencensus in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.11.4)
# Requirement already satisfied: fsspec in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (2025.2.0)
# Collecting ormsgpack==1.7.0 (from ray[all])
#   Downloading ormsgpack-1.7.0-cp310-cp310-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: prometheus_client>=0.7.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.21.0)
# Collecting gymnasium==1.0.0 (from ray[all])
#   Using cached gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: starlette in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.45.3)
# Requirement already satisfied: pyarrow>=9.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (19.0.0)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (3.11.10)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.4.0)
# Collecting scipy (from ray[all])
#   Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: fastapi in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.115.8)
# Collecting opentelemetry-api (from ray[all])
#   Downloading opentelemetry_api-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: watchfiles in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (1.0.4)
# Requirement already satisfied: aiohttp_cors in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from ray[all]) (0.7.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==1.0.0->ray[all]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==1.0.0->ray[all]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==1.0.0->ray[all]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[all]) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[all]) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[all]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[all]) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[all]) (1.18.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from aiohttp>=3.7->ray[all]) (5.0.1)
# Requirement already satisfied: colorama in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from click>=7.0->ray[all]) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas->ray[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas->ray[all]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pandas->ray[all]) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[all]) (2.27.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[all]) (3.10.0)
# Collecting fastrlock>=0.5 (from cupy-cuda12x->ray[all])
#   Downloading fastrlock-0.8.3-cp310-cp310-win_amd64.whl.metadata (7.9 kB)
# Collecting absl-py>=0.6.1 (from dm_tree->ray[all])
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: wrapt>=1.11.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from dm_tree->ray[all]) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from starlette->ray[all]) (4.6.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[all]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[all]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from jsonschema->ray[all]) (0.22.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[all]) (0.1.3)
# Requirement already satisfied: six~=1.16 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[all]) (1.16.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opencensus->ray[all]) (2.24.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opentelemetry-api->ray[all]) (1.2.13)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opentelemetry-api->ray[all]) (8.5.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.30.0 (from opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.30.0 (from opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.30.0->opentelemetry-exporter-otlp->ray[all]) (1.67.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.30.0 (from opentelemetry-exporter-otlp-proto-grpc==1.30.0->opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.30.0 (from opentelemetry-exporter-otlp-proto-grpc==1.30.0->opentelemetry-exporter-otlp->ray[all])
#   Downloading opentelemetry_proto-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.51b0 (from opentelemetry-sdk->ray[all])
#   Downloading opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[all]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[all]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from requests->ray[all]) (2025.1.31)
# Requirement already satisfied: cryptography<45,>=41.0.5 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pyOpenSSL->ray[all]) (43.0.3)
# Requirement already satisfied: h11>=0.8 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]) (1.0.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from uvicorn[standard]; extra == "all"->ray[all]) (15.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from anyio<5,>=3.6.2->starlette->ray[all]) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from anyio<5,>=3.6.2->starlette->ray[all]) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from cryptography<45,>=41.0.5->pyOpenSSL->ray[all]) (1.17.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (2.38.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api->ray[all]) (3.21.0)
# Requirement already satisfied: pycparser in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from cffi>=1.12->cryptography<45,>=41.0.5->pyOpenSSL->ray[all]) (2.21)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[all]) (0.6.1)
# Using cached gymnasium-1.0.0-py3-none-any.whl (958 kB)
# Downloading ormsgpack-1.7.0-cp310-cp310-win_amd64.whl (125 kB)
# Downloading cupy_cuda12x-13.3.0-cp310-cp310-win_amd64.whl (69.6 MB)
#    ---------------------------------------- 0.0/69.6 MB ? eta -:--:--
#    - -------------------------------------- 1.8/69.6 MB 9.1 MB/s eta 0:00:08
#    - -------------------------------------- 3.1/69.6 MB 8.4 MB/s eta 0:00:08
#    -- ------------------------------------- 4.5/69.6 MB 7.3 MB/s eta 0:00:09
#    --- ------------------------------------ 5.8/69.6 MB 6.9 MB/s eta 0:00:10
#    --- ------------------------------------ 6.8/69.6 MB 6.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 7.9/69.6 MB 6.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 8.9/69.6 MB 6.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 9.7/69.6 MB 5.7 MB/s eta 0:00:11
#    ------ --------------------------------- 10.5/69.6 MB 5.5 MB/s eta 0:00:11
#    ------ --------------------------------- 11.3/69.6 MB 5.3 MB/s eta 0:00:12
#    ------ --------------------------------- 12.1/69.6 MB 5.1 MB/s eta 0:00:12
#    ------- -------------------------------- 12.8/69.6 MB 5.0 MB/s eta 0:00:12
#    ------- -------------------------------- 13.6/69.6 MB 4.9 MB/s eta 0:00:12
#    -------- ------------------------------- 14.4/69.6 MB 4.8 MB/s eta 0:00:12
#    --------- ------------------------------ 16.3/69.6 MB 5.0 MB/s eta 0:00:11
#    ---------- ----------------------------- 17.6/69.6 MB 5.2 MB/s eta 0:00:11
#    ---------- ----------------------------- 18.6/69.6 MB 5.1 MB/s eta 0:00:10
#    ----------- ---------------------------- 19.9/69.6 MB 5.2 MB/s eta 0:00:10
#    ------------ --------------------------- 21.8/69.6 MB 5.3 MB/s eta 0:00:09
#    ------------- -------------------------- 24.1/69.6 MB 5.6 MB/s eta 0:00:09
#    --------------- ------------------------ 26.2/69.6 MB 5.8 MB/s eta 0:00:08
#    ---------------- ----------------------- 28.3/69.6 MB 6.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 30.1/69.6 MB 6.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 30.4/69.6 MB 6.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 30.9/69.6 MB 5.8 MB/s eta 0:00:07
#    ------------------ --------------------- 33.0/69.6 MB 5.9 MB/s eta 0:00:07
#    ------------------- -------------------- 34.6/69.6 MB 6.0 MB/s eta 0:00:06
#    --------------------- ------------------ 36.7/69.6 MB 6.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 38.5/69.6 MB 6.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 40.4/69.6 MB 6.3 MB/s eta 0:00:05
#    ------------------------ --------------- 42.7/69.6 MB 6.4 MB/s eta 0:00:05
#    ------------------------- -------------- 44.6/69.6 MB 6.5 MB/s eta 0:00:04
#    -------------------------- ------------- 46.7/69.6 MB 6.6 MB/s eta 0:00:04
#    ---------------------------- ----------- 48.8/69.6 MB 6.7 MB/s eta 0:00:04
#    ----------------------------- ---------- 50.6/69.6 MB 6.7 MB/s eta 0:00:03
#    ------------------------------ --------- 52.4/69.6 MB 6.8 MB/s eta 0:00:03
#    ------------------------------- -------- 54.5/69.6 MB 6.9 MB/s eta 0:00:03
#    ------------------------------- -------- 54.5/69.6 MB 6.9 MB/s eta 0:00:03
#    ------------------------------- -------- 55.6/69.6 MB 6.7 MB/s eta 0:00:03
#    ------------------------------- -------- 55.6/69.6 MB 6.7 MB/s eta 0:00:03
#    -------------------------------- ------- 56.9/69.6 MB 6.5 MB/s eta 0:00:02
#    --------------------------------- ------ 59.0/69.6 MB 6.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 60.8/69.6 MB 6.6 MB/s eta 0:00:02
#    ------------------------------------ --- 62.9/69.6 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 65.0/69.6 MB 6.8 MB/s eta 0:00:01
#    -------------------------------------- - 66.8/69.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  68.9/69.6 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  69.5/69.6 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 69.6/69.6 MB 6.7 MB/s eta 0:00:00
# Downloading dm_tree-0.1.9-cp310-cp310-win_amd64.whl (101 kB)
# Downloading lz4-4.4.3-cp310-cp310-win_amd64.whl (99 kB)
# Downloading opentelemetry_api-1.30.0-py3-none-any.whl (64 kB)
# Downloading opentelemetry_exporter_otlp-1.30.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.30.0-py3-none-any.whl (55 kB)
# Downloading opentelemetry_sdk-1.30.0-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl (177 kB)
# Downloading pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
# Downloading scipy-1.15.2-cp310-cp310-win_amd64.whl (41.2 MB)
#    ---------------------------------------- 0.0/41.2 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/41.2 MB 12.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/41.2 MB 11.9 MB/s eta 0:00:04
#    ------ --------------------------------- 7.1/41.2 MB 12.1 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/41.2 MB 12.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.8/41.2 MB 11.9 MB/s eta 0:00:03
#    ------------- -------------------------- 13.9/41.2 MB 11.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.5/41.2 MB 11.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 18.4/41.2 MB 11.2 MB/s eta 0:00:03
#    ------------------- -------------------- 20.4/41.2 MB 10.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.8/41.2 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 25.4/41.2 MB 11.0 MB/s eta 0:00:02
#    -------------------------- ------------- 27.8/41.2 MB 11.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.4/41.2 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 32.8/41.2 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.1/41.2 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 37.5/41.2 MB 11.1 MB/s eta 0:00:01
#    -------------------------------------- - 40.1/41.2 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 41.2/41.2 MB 10.9 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading fastrlock-0.8.3-cp310-cp310-win_amd64.whl (30 kB)
# Installing collected packages: fastrlock, scipy, ormsgpack, opentelemetry-proto, lz4, gymnasium, cupy-cuda12x, absl-py, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, dm_tree, pyOpenSSL, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-exporter-otlp
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.29.1
#     Uninstalling gymnasium-0.29.1:
#       Successfully uninstalled gymnasium-0.29.1
# Successfully installed absl-py-2.1.0 cupy-cuda12x-13.3.0 dm_tree-0.1.9 fastrlock-0.8.3 gymnasium-1.0.0 lz4-4.4.3 opentelemetry-api-1.30.0 opentelemetry-exporter-otlp-1.30.0 opentelemetry-exporter-otlp-proto-common-1.30.0 opentelemetry-exporter-otlp-proto-grpc-1.30.0 opentelemetry-exporter-otlp-proto-http-1.30.0 opentelemetry-proto-1.30.0 opentelemetry-sdk-1.30.0 opentelemetry-semantic-conventions-0.51b0 ormsgpack-1.7.0 pyOpenSSL-25.0.0 scipy-1.15.2

# %%
# !pip uninstall
# !pip install gymnasium==0.29.1
# Out:
# ERROR: You must give at least one requirement to uninstall (see "pip help uninstall")
# Collecting gymnasium==0.29.1
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (2.2.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\ritwi\anaconda3\envs\rl_trading\lib\site-packages (from gymnasium==0.29.1) (0.0.4)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0
#     Uninstalling gymnasium-1.0.0:
#       Successfully uninstalled gymnasium-1.0.0
# Successfully installed gymnasium-0.29.1
