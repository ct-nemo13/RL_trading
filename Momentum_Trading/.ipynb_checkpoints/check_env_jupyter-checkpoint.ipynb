# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Dec 27 18:11:57 2023

@author: ritwi
"""
import gymnasium as gym
import time
import math
import matplotlib.pyplot as plt


'Registering the Gym Environment'
gym.register(id='SingleStockLongOnly', entry_point='main_Env:SingleStockLongOnly')


test_agent_id = 'random_agent'
episodes = 3


'Calling the Environment'
env = gym.make('SingleStockLongOnly',
               env_config={'mode':'test',
                           'test_agent_id': test_agent_id,
                           'data_dir':'data_dir/train_data',
                           'episode_length_in_steps': 5,                      
                           'look_back_window': 3,
                           'initial_fund_in_money': 500000,
                           'fee_percentage': 0.1,
                           'max_fee': 40,
                           'lowest_acceptabl_net_worth': 0.75,
                           'position_per_action_value': 0.5}
               )    

print('\nObservation Sample\n', env.observation_space)
print('\nObservation Sample\n', env.observation_space.sample())
print('\nAction Sample\n', env.action_space.sample())


'Play an Eplisode with a Random Agent'
reward_list = []
for episode in range(episodes):
    
    'Starting countdown to measure the time taken for one episode'
    start = time.time()
    done = False
    obs = env.reset()
    print('\nObservation after Reset:', obs)
    total_reward = 0
    score = 0
    while not done:
        'Taking an random action'
        random_action = env.action_space.sample()
        print('\nAction taken by the agent:',random_action)
        
        'Getting the observation, reward and done status from the environment'
        obs, reward, done, info = env.step(random_action)
        print('\nInfo:',info)
        print('\nReward at the step:', reward)
        print('\nObservation at the step:', obs)
        
        total_reward += reward
    
    reward_list.append((math.exp(total_reward)-1) * 100)
    end = time.time()
    print(f"Time taken for the episode: {(end-start)*10**3:.03f}ms")
    
    
'Plotting a Reward histogram'
plt.hist(reward_list, bins=30, color='blue', edgecolor='black')
'Adding labels and title'
plt.xlabel('% Reward')
plt.ylabel('Frequency')
plt.title('Reward Histogram')

'Save the histogram plot.'
file_path = 'test_logs/' + test_agent_id + '/Reward_in_Percentage_Histogram.jpeg'


plt.savefig(file_path, dpi=500)

'Display the plot'
plt.show()
# Out:
# The "test_logs" directory already exists.
#
# List of Stocks:
#  ['APOLLOTYRE', 'AUROPHARMA', 'AXISBANK', 'BAJFINANCE', 'BHARATFORG', 'BHARTIARTL', 'CANBK', 'DIVISLAB', 'DLF', 'DRREDDY', 'GLENMARK', 'HCLTECH', 'HEROMOTOCO', 'HINDALCO', 'ICICIBANK', 'INFY', 'JSWSTEEL', 'JUBLFOOD', 'MARUTI', 'RELIANCE', 'SBIN', 'TATAMOTORS', 'TATASTEEL', 'TCS', 'WIPRO']
#
# Observation Sample
#  Box(-inf, inf, (3, 10), float64)
#
# Observation Sample
#  [[ 0.6795022  -0.01007017 -0.77314367 -0.52887867 -0.51129441 -2.05229026
#    0.25233977 -0.32253689  0.02037227  1.91375035]
#  [-1.03225448 -0.14314982  0.55864828 -0.36378139  0.13132283  1.13495944
#   -0.51388331  0.38851938  0.09413012  1.22976133]
#  [ 2.15139704  0.14160081  0.46744728  1.21220623 -0.41483258 -0.54522738
#    0.68582317 -0.167325    0.22935318 -1.12121219]]
#
# Action Sample
#  2
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: DIVISLAB
#
# The dataframe containing historical data of the selected stock:
#                          open     high      low    close  volume
# date
# 2023-06-23 13:10:00  3518.15  3520.90  3516.00  3517.05    1323
# 2023-06-23 13:15:00  3517.05  3519.10  3515.00  3515.00    2101
# 2023-06-23 13:20:00  3515.10  3518.55  3515.00  3515.15    2863
# 2023-06-23 13:25:00  3515.15  3518.10  3515.00  3516.35    3244
# 2023-06-23 13:30:00  3516.35  3516.50  3504.00  3504.90    6097
# ...                      ...      ...      ...      ...     ...
# 2023-08-30 11:50:00  3657.10  3658.60  3657.10  3657.50    1234
# 2023-08-30 11:55:00  3657.50  3661.95  3657.50  3661.95    1806
# 2023-08-30 12:00:00  3661.75  3665.35  3657.55  3663.20   53662
# 2023-08-30 12:05:00  3663.20  3665.30  3660.10  3660.10    2318
# 2023-08-30 12:10:00  3660.00  3662.00  3657.50  3658.90    1180
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-07-26 12:50:00
#
# The start time at the reset: 2023-07-26 12:05:00
#
# Int index of the df from where observation starts at reset: 1635
#
# Int index of the df where observation end at reset: 1637
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 497126.60000000003
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 497669.3
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 497294.10000000003
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[3.70735e+03 3.70990e+03 3.70110e+03 3.70735e+03 2.26900e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.71055e+03 3.71395e+03 3.70715e+03 3.71055e+03 7.44200e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.70940e+03 3.71115e+03 3.70720e+03 3.70940e+03 3.37600e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Done Status after the reset: False
# The test episode count: 1
#
# The reset is completed
#
# Observation after Reset: [[3.70735e+03 3.70990e+03 3.70110e+03 3.70735e+03 2.26900e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.71055e+03 3.71395e+03 3.70715e+03 3.71055e+03 7.44200e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.70940e+03 3.71115e+03 3.70720e+03 3.70940e+03 3.37600e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 3711.4276117620057
#
# Hold Action
#
# Reward at the step: 0.0
# The appended action list: [np.int64(0)]
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 497542.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-07-26 12:10:00 False
# The updated observation at the end of the step:
#  [[3.71055e+03 3.71395e+03 3.70715e+03 3.71055e+03 7.44200e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.70940e+03 3.71115e+03 3.70720e+03 3.70940e+03 3.37600e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.71070e+03 3.71300e+03 3.70620e+03 3.71130e+03 5.04800e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
# {'Time': Timestamp('2023-07-26 12:10:00')}
#
# Info: {'Time': Timestamp('2023-07-26 12:10:00')}
#
# Reward at the step: 0.0
#
# Observation at the step: [[3.71055e+03 3.71395e+03 3.70715e+03 3.71055e+03 7.44200e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.70940e+03 3.71115e+03 3.70720e+03 3.70940e+03 3.37600e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [3.71070e+03 3.71300e+03 3.70620e+03 3.71130e+03 5.04800e+03 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 0
#
# The action, applied to the env by the agent: 0
#
# The actual action after scalling: -2
#
# Stock Holdings 0
#
# Action: -2
#
# Fund_Status: 1
#
# Episode is terminating due to wrong Sell Action
#
# Penalty for Wrong Action: -10
#
# The execution price: 3710.763146378367
#
# Sell Action
#
#
# Stock Reserve 0
#
# Actual stock quantity to be sold 0
#
# Actual money earned in the stock selling: 0.0
#
# The total fee to be paid 0.0
# Reward at the step: -10.0
# The appended action list: [np.int64(0), np.int64(-2)]
#
# The net Worth at the end of the episode: 500000.0
#
#  The episode length was: 1
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:168: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.deprecation(
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:181: DeprecationWarning: WARN: Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.deprecation(
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:189: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# C:\Users\ritwi\anaconda3\envs\RL_Trading\lib\site-packages\gymnasium\utils\passive_env_checker.py:213: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000.0
#
# The Effective Money Reserve: 497783.2
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-07-26 12:15:00 True
# The updated observation at the end of the step:
#  [[ 3.70940e+03  3.71115e+03  3.70720e+03  3.70940e+03  3.37600e+03
#    1.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00  0.00000e+00]
#  [ 3.71070e+03  3.71300e+03  3.70620e+03  3.71130e+03  5.04800e+03
#    1.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00  0.00000e+00]
#  [ 3.71205e+03  3.71480e+03  3.70920e+03  3.71205e+03  3.61800e+03
#    1.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00 -1.00000e+01]]
# {'Time': Timestamp('2023-07-26 12:15:00')}
#
# Info: {'Time': Timestamp('2023-07-26 12:15:00')}
#
# Reward at the step: -10.0
#
# Observation at the step: [[ 3.70940e+03  3.71115e+03  3.70720e+03  3.70940e+03  3.37600e+03
#    1.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00  0.00000e+00]
#  [ 3.71070e+03  3.71300e+03  3.70620e+03  3.71130e+03  5.04800e+03
#    1.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00  0.00000e+00]
#  [ 3.71205e+03  3.71480e+03  3.70920e+03  3.71205e+03  3.61800e+03
#    1.00000e+00  0.00000e+00  1.00000e+00  1.00000e+00 -1.00000e+01]]
# Time taken for the episode: 1260.643ms
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: DLF
#
# The dataframe containing historical data of the selected stock:
#                         open    high     low   close  volume
# date
# 2023-06-23 13:25:00  478.75  479.70  478.55  479.20   16090
# 2023-06-23 13:30:00  479.20  479.30  478.80  479.15   10054
# 2023-06-23 13:35:00  479.15  479.85  479.00  479.65    8538
# 2023-06-23 13:40:00  479.65  480.75  479.40  480.10   16430
# 2023-06-23 13:45:00  480.10  481.20  480.10  481.20   13754
# ...                     ...     ...     ...     ...     ...
# 2023-08-30 12:05:00  501.35  501.90  501.25  501.90   78308
# 2023-08-30 12:10:00  501.90  501.95  501.00  501.00   39195
# 2023-08-30 12:15:00  501.00  501.25  500.50  500.50   20513
# 2023-08-30 12:20:00  500.50  500.50  499.80  500.05   29556
# 2023-08-30 12:25:00  500.10  501.00  499.80  500.80   28240
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-07-21 11:30:00
#
# The start time at the reset: 2023-07-21 10:45:00
#
# Int index of the df from where observation starts at reset: 1391
#
# Int index of the df where observation end at reset: 1393
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499490.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499648.69999999995
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499895.8
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[5.0035e+02 5.0200e+02 5.0000e+02 5.0035e+02 6.0159e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0045e+02 5.0065e+02 4.9980e+02 5.0045e+02 1.4114e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0050e+02 5.0140e+02 5.0025e+02 5.0050e+02 1.9693e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]]
#
# Done Status after the reset: False
# The test episode count: 2
#
# The reset is completed
#
# Observation after Reset: [[5.0035e+02 5.0200e+02 5.0000e+02 5.0035e+02 6.0159e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0045e+02 5.0065e+02 4.9980e+02 5.0045e+02 1.4114e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0050e+02 5.0140e+02 5.0025e+02 5.0050e+02 1.9693e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 500.49409437833543
#
# Hold Action
#
# Reward at the step: 0.0
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0)]
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499499.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-07-21 10:50:00 False
# The updated observation at the end of the step:
#  [[5.0045e+02 5.0065e+02 4.9980e+02 5.0045e+02 1.4114e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0050e+02 5.0140e+02 5.0025e+02 5.0050e+02 1.9693e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0005e+02 5.0050e+02 4.9995e+02 5.0005e+02 1.1948e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]]
# {'Time': Timestamp('2023-07-21 10:50:00')}
#
# Info: {'Time': Timestamp('2023-07-21 10:50:00')}
#
# Reward at the step: 0.0
#
# Observation at the step: [[5.0045e+02 5.0065e+02 4.9980e+02 5.0045e+02 1.4114e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0050e+02 5.0140e+02 5.0025e+02 5.0050e+02 1.9693e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]
#  [5.0005e+02 5.0050e+02 4.9995e+02 5.0005e+02 1.1948e+04 1.0000e+00
#   0.0000e+00 1.0000e+00 1.0000e+00 0.0000e+00]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# Stock Holdings 0
#
# Action: -1
#
# Fund_Status: 1
#
# Episode is terminating due to wrong Sell Action
#
# Penalty for Wrong Action: -10
#
# The execution price: 499.56875990640947
#
# Sell Action
#
#
# Stock Reserve 0
#
# Actual stock quantity to be sold 0
#
# Actual money earned in the stock selling: 0.0
#
# The total fee to be paid 0.0
# Reward at the step: -10.0
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1)]
#
# The net Worth at the end of the episode: 500000.0
#
#  The episode length was: 1
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000.0
#
# The Effective Money Reserve: 499548.9
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-07-21 10:55:00 True
# The updated observation at the end of the step:
#  [[ 5.0050e+02  5.0140e+02  5.0025e+02  5.0050e+02  1.9693e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 5.0005e+02  5.0050e+02  4.9995e+02  5.0005e+02  1.1948e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 5.0020e+02  5.0055e+02  4.9945e+02  5.0020e+02  2.0576e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00 -1.0000e+01]]
# {'Time': Timestamp('2023-07-21 10:55:00')}
#
# Info: {'Time': Timestamp('2023-07-21 10:55:00')}
#
# Reward at the step: -10.0
#
# Observation at the step: [[ 5.0050e+02  5.0140e+02  5.0025e+02  5.0050e+02  1.9693e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 5.0005e+02  5.0050e+02  4.9995e+02  5.0005e+02  1.1948e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00  0.0000e+00]
#  [ 5.0020e+02  5.0055e+02  4.9945e+02  5.0020e+02  2.0576e+04  1.0000e+00
#    0.0000e+00  1.0000e+00  1.0000e+00 -1.0000e+01]]
# Time taken for the episode: 697.621ms
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: SBIN
#
# The dataframe containing historical data of the selected stock:
#                         open    high     low   close  volume
# date
# 2023-06-23 13:00:00  558.60  558.70  557.65  558.00  138160
# 2023-06-23 13:05:00  557.90  558.35  557.70  558.15   54003
# 2023-06-23 13:10:00  558.10  558.35  557.80  558.05   67837
# 2023-06-23 13:15:00  558.05  558.35  557.80  558.00  132349
# 2023-06-23 13:20:00  558.05  558.25  557.65  557.80   80444
# ...                     ...     ...     ...     ...     ...
# 2023-08-30 11:40:00  575.05  575.15  573.90  574.20  683828
# 2023-08-30 11:45:00  574.50  574.50  573.85  573.95  107043
# 2023-08-30 11:50:00  573.90  574.30  573.80  574.10  110644
# 2023-08-30 11:55:00  574.10  574.20  573.85  574.00   77238
# 2023-08-30 12:00:00  573.95  574.10  573.95  574.00   99160
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-08-08 12:40:00
#
# The start time at the reset: 2023-08-08 11:55:00
#
# Int index of the df from where observation starts at reset: 2310
#
# Int index of the df where observation end at reset: 2312
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499625.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499625.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499928.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[5.70900e+02 5.71000e+02 5.70050e+02 5.70900e+02 2.00381e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [5.70950e+02 5.71000e+02 5.70050e+02 5.70800e+02 1.60479e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [5.71450e+02 5.72000e+02 5.70500e+02 5.71400e+02 2.52813e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Done Status after the reset: False
# The test episode count: 3
#
# The reset is completed
#
# Observation after Reset: [[5.70900e+02 5.71000e+02 5.70050e+02 5.70900e+02 2.00381e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [5.70950e+02 5.71000e+02 5.70050e+02 5.70800e+02 1.60479e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [5.71450e+02 5.72000e+02 5.70500e+02 5.71400e+02 2.52813e+05 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 4
#
# The action, applied to the env by the agent: 4
#
# The actual action after scalling: 2
#
# The execution price: 571.3243563880084
#
# Buy Action
#
#
# Target position to buy in money: 499960.0
#
# Actual stock quantity bought: 875.0
#
# The actual money spent to purchase stock: 499908.8118395073
#
# The total fee to be paid 40
# Reward at the step: -0.0010857128519695472
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2)]
#
# The Normalized Money Reserve: 0.0001023763209853787
#
# The Normalized Stock Reserve: 0.9988125
#
# The Normalized Net Worth: 0.9989148763209854
#
# The Money Reserve: 51.18816049268935
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 875.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-08-08 12:00:00 False
# The updated observation at the end of the step:
#  [[ 5.70950000e+02  5.71000000e+02  5.70050000e+02  5.70800000e+02
#    1.60479000e+05  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 5.71450000e+02  5.72000000e+02  5.70500000e+02  5.71400000e+02
#    2.52813000e+05  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 5.70750000e+02  5.71650000e+02  5.70500000e+02  5.70750000e+02
#    3.14941000e+05  1.02376321e-04  9.98812500e-01  9.98914876e-01
#    0.00000000e+00 -1.08571285e-03]]
# {'Time': Timestamp('2023-08-08 12:00:00')}
#
# Info: {'Time': Timestamp('2023-08-08 12:00:00')}
#
# Reward at the step: -0.0010857128519695472
#
# Observation at the step: [[ 5.70950000e+02  5.71000000e+02  5.70050000e+02  5.70800000e+02
#    1.60479000e+05  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 5.71450000e+02  5.72000000e+02  5.70500000e+02  5.71400000e+02
#    2.52813000e+05  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 5.70750000e+02  5.71650000e+02  5.70500000e+02  5.70750000e+02
#    3.14941000e+05  1.02376321e-04  9.98812500e-01  9.98914876e-01
#    0.00000000e+00 -1.08571285e-03]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 570.639420951984
#
# Hold Action
#
# Reward at the step: -8.759888813495524e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0)]
#
# The Normalized Money Reserve: 0.0001023763209853787
#
# The Normalized Stock Reserve: 0.9987250000000001
#
# The Normalized Net Worth: 0.9988273763209855
#
# The Money Reserve: 51.18816049268935
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 875.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-08-08 12:05:00 False
# The updated observation at the end of the step:
#  [[ 5.71450000e+02  5.72000000e+02  5.70500000e+02  5.71400000e+02
#    2.52813000e+05  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 5.70750000e+02  5.71650000e+02  5.70500000e+02  5.70750000e+02
#    3.14941000e+05  1.02376321e-04  9.98812500e-01  9.98914876e-01
#    0.00000000e+00 -1.08571285e-03]
#  [ 5.70650000e+02  5.71150000e+02  5.70300000e+02  5.70700000e+02
#    5.14788000e+05  1.02376321e-04  9.98725000e-01  9.98827376e-01
#    0.00000000e+00 -8.75988881e-05]]
# {'Time': Timestamp('2023-08-08 12:05:00')}
#
# Info: {'Time': Timestamp('2023-08-08 12:05:00')}
#
# Reward at the step: -8.759888813495524e-05
#
# Observation at the step: [[ 5.71450000e+02  5.72000000e+02  5.70500000e+02  5.71400000e+02
#    2.52813000e+05  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 5.70750000e+02  5.71650000e+02  5.70500000e+02  5.70750000e+02
#    3.14941000e+05  1.02376321e-04  9.98812500e-01  9.98914876e-01
#    0.00000000e+00 -1.08571285e-03]
#  [ 5.70650000e+02  5.71150000e+02  5.70300000e+02  5.70700000e+02
#    5.14788000e+05  1.02376321e-04  9.98725000e-01  9.98827376e-01
#    0.00000000e+00 -8.75988881e-05]]
#
# Action taken by the agent: 4
#
# The action, applied to the env by the agent: 4
#
# The actual action after scalling: 2
#
# Money Reserve 51.18816049268935
#
# Effective Money Reserve 0.0
#
# Action: 2
#
# Fund_Status: 0
#
# Episode is terminating due to wrong Buy Action
#
# Penalty for Wrong Action: -10
#
# The execution price: 571.1965912850034
#
# Buy Action
#
#
# Target position to buy in money: 11.188160492689349
#
# Actual stock quantity bought: 0.0
#
# The actual money spent to purchase stock: 0.0
#
# The total fee to be paid 0.0
# Reward at the step: -9.998949319457807
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2)]
#
# The net Worth at the end of the episode: 499938.68816049263
#
#  The episode length was: 2
# The Normalized Money Reserve: 0.0001023763209853787
#
# The Normalized Stock Reserve: 0.9997749999999999
#
# The Normalized Net Worth: 0.9998773763209853
#
# The Money Reserve: 51.18816049268935
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 875.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-08-08 12:10:00 True
# The updated observation at the end of the step:
#  [[ 5.70750000e+02  5.71650000e+02  5.70500000e+02  5.70750000e+02
#    3.14941000e+05  1.02376321e-04  9.98812500e-01  9.98914876e-01
#    0.00000000e+00 -1.08571285e-03]
#  [ 5.70650000e+02  5.71150000e+02  5.70300000e+02  5.70700000e+02
#    5.14788000e+05  1.02376321e-04  9.98725000e-01  9.98827376e-01
#    0.00000000e+00 -8.75988881e-05]
#  [ 5.71450000e+02  5.71550000e+02  5.70300000e+02  5.71300000e+02
#    2.53230000e+05  1.02376321e-04  9.99775000e-01  9.99877376e-01
#    0.00000000e+00 -9.99894932e+00]]
# {'Time': Timestamp('2023-08-08 12:10:00')}
#
# Info: {'Time': Timestamp('2023-08-08 12:10:00')}
#
# Reward at the step: -9.998949319457807
#
# Observation at the step: [[ 5.70750000e+02  5.71650000e+02  5.70500000e+02  5.70750000e+02
#    3.14941000e+05  1.02376321e-04  9.98812500e-01  9.98914876e-01
#    0.00000000e+00 -1.08571285e-03]
#  [ 5.70650000e+02  5.71150000e+02  5.70300000e+02  5.70700000e+02
#    5.14788000e+05  1.02376321e-04  9.98725000e-01  9.98827376e-01
#    0.00000000e+00 -8.75988881e-05]
#  [ 5.71450000e+02  5.71550000e+02  5.70300000e+02  5.71300000e+02
#    2.53230000e+05  1.02376321e-04  9.99775000e-01  9.99877376e-01
#    0.00000000e+00 -9.99894932e+00]]
# Time taken for the episode: 605.918ms
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: INFY
#
# The dataframe containing historical data of the selected stock:
#                          open     high      low    close  volume
# date
# 2023-06-23 13:15:00  1275.00  1275.40  1274.50  1275.20   64014
# 2023-06-23 13:20:00  1275.20  1275.75  1274.75  1275.20   53502
# 2023-06-23 13:25:00  1275.20  1275.70  1274.35  1274.45   50843
# 2023-06-23 13:30:00  1274.90  1275.00  1274.35  1274.45   44872
# 2023-06-23 13:35:00  1274.45  1275.35  1274.40  1275.00   46606
# ...                      ...      ...      ...      ...     ...
# 2023-08-30 11:55:00  1429.60  1431.00  1429.60  1430.60   44518
# 2023-08-30 12:00:00  1430.60  1431.20  1430.20  1430.70   30206
# 2023-08-30 12:05:00  1430.50  1430.70  1430.00  1430.25   20767
# 2023-08-30 12:10:00  1430.25  1430.95  1430.20  1430.60   21505
# 2023-08-30 12:15:00  1430.55  1430.65  1430.20  1430.30   17495
#
# [3439 rows x 5 columns]
#
# The episode end time: 2023-06-26 14:30:00
#
# The start time at the reset: 2023-06-26 13:45:00
#
# Int index of the df from where observation starts at reset: 79
#
# Int index of the df where observation end at reset: 81
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499483.35000000003
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499503.0
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499483.35000000003
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# The Observation after the Reset:
#  [[1.27020e+03 1.27095e+03 1.27015e+03 1.27045e+03 2.07330e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27045e+03 1.27100e+03 1.27010e+03 1.27090e+03 1.87260e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27050e+03 1.27095e+03 1.27000e+03 1.27035e+03 3.24180e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Done Status after the reset: False
# The test episode count: 4
#
# The reset is completed
#
# Observation after Reset: [[1.27020e+03 1.27095e+03 1.27015e+03 1.27045e+03 2.07330e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27045e+03 1.27100e+03 1.27010e+03 1.27090e+03 1.87260e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27050e+03 1.27095e+03 1.27000e+03 1.27035e+03 3.24180e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 1270.1265934659511
#
# Hold Action
#
# Reward at the step: 0.0
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0)]
#
# The Normalized Money Reserve: 1.0
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0
#
# The Money Reserve: 500000
#
# The Effective Money Reserve: 499306.5
#
# The Stock Reserve in Numbers: 0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-06-26 13:50:00 False
# The updated observation at the end of the step:
#  [[1.27045e+03 1.27100e+03 1.27010e+03 1.27090e+03 1.87260e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27050e+03 1.27095e+03 1.27000e+03 1.27035e+03 3.24180e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27035e+03 1.27050e+03 1.27000e+03 1.27035e+03 1.96640e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
# {'Time': Timestamp('2023-06-26 13:50:00')}
#
# Info: {'Time': Timestamp('2023-06-26 13:50:00')}
#
# Reward at the step: 0.0
#
# Observation at the step: [[1.27045e+03 1.27100e+03 1.27010e+03 1.27090e+03 1.87260e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27050e+03 1.27095e+03 1.27000e+03 1.27035e+03 3.24180e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]
#  [1.27035e+03 1.27050e+03 1.27000e+03 1.27035e+03 1.96640e+04 1.00000e+00
#   0.00000e+00 1.00000e+00 1.00000e+00 0.00000e+00]]
#
# Action taken by the agent: 3
#
# The action, applied to the env by the agent: 3
#
# The actual action after scalling: 1
#
# The execution price: 1270.0345777055072
#
# Buy Action
#
#
# Target position to buy in money: 249980.0
#
# Actual stock quantity bought: 196.0
#
# The actual money spent to purchase stock: 248926.7772302794
#
# The total fee to be paid 40
# Reward at the step: -9.355883705031655e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1)]
#
# The Normalized Money Reserve: 0.5020664455394412
#
# The Normalized Stock Reserve: 0.49784
#
# The Normalized Net Worth: 0.9999064455394413
#
# The Money Reserve: 251033.2227697206
#
# The Effective Money Reserve: 250268.80000000002
#
# The Stock Reserve in Numbers: 196.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-26 13:55:00 False
# The updated observation at the end of the step:
#  [[ 1.27050000e+03  1.27095000e+03  1.27000000e+03  1.27035000e+03
#    3.24180000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 1.27035000e+03  1.27050000e+03  1.27000000e+03  1.27035000e+03
#    1.96640000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 1.27025000e+03  1.27040000e+03  1.27000000e+03  1.27000000e+03
#    3.20640000e+04  5.02066446e-01  4.97840000e-01  9.99906446e-01
#    2.00000000e+00 -9.35588371e-05]]
# {'Time': Timestamp('2023-06-26 13:55:00')}
#
# Info: {'Time': Timestamp('2023-06-26 13:55:00')}
#
# Reward at the step: -9.355883705031655e-05
#
# Observation at the step: [[ 1.27050000e+03  1.27095000e+03  1.27000000e+03  1.27035000e+03
#    3.24180000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 1.27035000e+03  1.27050000e+03  1.27000000e+03  1.27035000e+03
#    1.96640000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 1.27025000e+03  1.27040000e+03  1.27000000e+03  1.27000000e+03
#    3.20640000e+04  5.02066446e-01  4.97840000e-01  9.99906446e-01
#    2.00000000e+00 -9.35588371e-05]]
#
# Action taken by the agent: 4
#
# The action, applied to the env by the agent: 4
#
# The actual action after scalling: 2
#
# The execution price: 1269.9561194827995
#
# Buy Action
#
#
# Target position to buy in money: 250993.2227697206
#
# Actual stock quantity bought: 197.0
#
# The actual money spent to purchase stock: 250181.3555381115
#
# The total fee to be paid 40
# Reward at the step: -6.271891046262657e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2)]
#
# The Normalized Money Reserve: 0.001623734463218192
#
# The Normalized Stock Reserve: 0.99822
#
# The Normalized Net Worth: 0.9998437344632182
#
# The Money Reserve: 811.867231609096
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 393.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-06-26 14:00:00 False
# The updated observation at the end of the step:
#  [[ 1.27035000e+03  1.27050000e+03  1.27000000e+03  1.27035000e+03
#    1.96640000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 1.27025000e+03  1.27040000e+03  1.27000000e+03  1.27000000e+03
#    3.20640000e+04  5.02066446e-01  4.97840000e-01  9.99906446e-01
#    2.00000000e+00 -9.35588371e-05]
#  [ 1.27000000e+03  1.27025000e+03  1.26945000e+03  1.27000000e+03
#    2.42720000e+04  1.62373446e-03  9.98220000e-01  9.99843734e-01
#    0.00000000e+00 -6.27189105e-05]]
# {'Time': Timestamp('2023-06-26 14:00:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:00:00')}
#
# Reward at the step: -6.271891046262657e-05
#
# Observation at the step: [[ 1.27035000e+03  1.27050000e+03  1.27000000e+03  1.27035000e+03
#    1.96640000e+04  1.00000000e+00  0.00000000e+00  1.00000000e+00
#    1.00000000e+00  0.00000000e+00]
#  [ 1.27025000e+03  1.27040000e+03  1.27000000e+03  1.27000000e+03
#    3.20640000e+04  5.02066446e-01  4.97840000e-01  9.99906446e-01
#    2.00000000e+00 -9.35588371e-05]
#  [ 1.27000000e+03  1.27025000e+03  1.26945000e+03  1.27000000e+03
#    2.42720000e+04  1.62373446e-03  9.98220000e-01  9.99843734e-01
#    0.00000000e+00 -6.27189105e-05]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# The execution price: 1270.4760449804166
#
# Sell Action
#
#
# Stock Reserve 393.0
#
# Actual stock quantity to be sold 196
#
# Actual money earned in the stock selling: 249013.30481616166
#
# The total fee to be paid 40
# Reward at the step: 0.00010662061015928163
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1)]
#
# The Normalized Money Reserve: 0.4995703440955415
#
# The Normalized Stock Reserve: 0.50038
#
# The Normalized Net Worth: 0.9999503440955415
#
# The Money Reserve: 249785.17204777076
#
# The Effective Money Reserve: 249018.0
#
# The Stock Reserve in Numbers: 197.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-06-26 14:05:00 False
# The updated observation at the end of the step:
#  [[ 1.27025000e+03  1.27040000e+03  1.27000000e+03  1.27000000e+03
#    3.20640000e+04  5.02066446e-01  4.97840000e-01  9.99906446e-01
#    2.00000000e+00 -9.35588371e-05]
#  [ 1.27000000e+03  1.27025000e+03  1.26945000e+03  1.27000000e+03
#    2.42720000e+04  1.62373446e-03  9.98220000e-01  9.99843734e-01
#    0.00000000e+00 -6.27189105e-05]
#  [ 1.27050000e+03  1.27050000e+03  1.26970000e+03  1.27000000e+03
#    2.55160000e+04  4.99570344e-01  5.00380000e-01  9.99950344e-01
#    2.00000000e+00  1.06620610e-04]]
# {'Time': Timestamp('2023-06-26 14:05:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:05:00')}
#
# Reward at the step: 0.00010662061015928163
#
# Observation at the step: [[ 1.27025000e+03  1.27040000e+03  1.27000000e+03  1.27000000e+03
#    3.20640000e+04  5.02066446e-01  4.97840000e-01  9.99906446e-01
#    2.00000000e+00 -9.35588371e-05]
#  [ 1.27000000e+03  1.27025000e+03  1.26945000e+03  1.27000000e+03
#    2.42720000e+04  1.62373446e-03  9.98220000e-01  9.99843734e-01
#    0.00000000e+00 -6.27189105e-05]
#  [ 1.27050000e+03  1.27050000e+03  1.26970000e+03  1.27000000e+03
#    2.55160000e+04  4.99570344e-01  5.00380000e-01  9.99950344e-01
#    2.00000000e+00  1.06620610e-04]]
#
# Action taken by the agent: 0
#
# The action, applied to the env by the agent: 0
#
# The actual action after scalling: -2
#
# The execution price: 1270.0366878221787
#
# Sell Action
#
#
# Stock Reserve 197.0
#
# Actual stock quantity to be sold 197
#
# Actual money earned in the stock selling: 250197.2275009692
#
# The total fee to be paid 40
# Reward at the step: -6.555040129999113e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2)]
#
# The Normalized Money Reserve: 0.9998847990974798
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 0.9998847990974798
#
# The Money Reserve: 499942.39954873995
#
# The Effective Money Reserve: 499463.7
#
# The Stock Reserve in Numbers: 0.0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-06-26 14:10:00 False
# The updated observation at the end of the step:
#  [[ 1.27000000e+03  1.27025000e+03  1.26945000e+03  1.27000000e+03
#    2.42720000e+04  1.62373446e-03  9.98220000e-01  9.99843734e-01
#    0.00000000e+00 -6.27189105e-05]
#  [ 1.27050000e+03  1.27050000e+03  1.26970000e+03  1.27000000e+03
#    2.55160000e+04  4.99570344e-01  5.00380000e-01  9.99950344e-01
#    2.00000000e+00  1.06620610e-04]
#  [ 1.27085000e+03  1.27090000e+03  1.26955000e+03  1.27055000e+03
#    2.52630000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00 -6.55504013e-05]]
# {'Time': Timestamp('2023-06-26 14:10:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:10:00')}
#
# Reward at the step: -6.555040129999113e-05
#
# Observation at the step: [[ 1.27000000e+03  1.27025000e+03  1.26945000e+03  1.27000000e+03
#    2.42720000e+04  1.62373446e-03  9.98220000e-01  9.99843734e-01
#    0.00000000e+00 -6.27189105e-05]
#  [ 1.27050000e+03  1.27050000e+03  1.26970000e+03  1.27000000e+03
#    2.55160000e+04  4.99570344e-01  5.00380000e-01  9.99950344e-01
#    2.00000000e+00  1.06620610e-04]
#  [ 1.27085000e+03  1.27090000e+03  1.26955000e+03  1.27055000e+03
#    2.52630000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00 -6.55504013e-05]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 1270.1359574521764
#
# Hold Action
#
# Reward at the step: 0.0
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0)]
#
# The Normalized Money Reserve: 0.9998847990974798
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 0.9998847990974798
#
# The Money Reserve: 499942.39954873995
#
# The Effective Money Reserve: 499581.60000000003
#
# The Stock Reserve in Numbers: 0.0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-06-26 14:15:00 False
# The updated observation at the end of the step:
#  [[ 1.27050000e+03  1.27050000e+03  1.26970000e+03  1.27000000e+03
#    2.55160000e+04  4.99570344e-01  5.00380000e-01  9.99950344e-01
#    2.00000000e+00  1.06620610e-04]
#  [ 1.27085000e+03  1.27090000e+03  1.26955000e+03  1.27055000e+03
#    2.52630000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00 -6.55504013e-05]
#  [ 1.26965000e+03  1.27120000e+03  1.26950000e+03  1.26995000e+03
#    2.78500000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00  0.00000000e+00]]
# {'Time': Timestamp('2023-06-26 14:15:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:15:00')}
#
# Reward at the step: 0.0
#
# Observation at the step: [[ 1.27050000e+03  1.27050000e+03  1.26970000e+03  1.27000000e+03
#    2.55160000e+04  4.99570344e-01  5.00380000e-01  9.99950344e-01
#    2.00000000e+00  1.06620610e-04]
#  [ 1.27085000e+03  1.27090000e+03  1.26955000e+03  1.27055000e+03
#    2.52630000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00 -6.55504013e-05]
#  [ 1.26965000e+03  1.27120000e+03  1.26950000e+03  1.26995000e+03
#    2.78500000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00  0.00000000e+00]]
#
# Action taken by the agent: 4
#
# The action, applied to the env by the agent: 4
#
# The actual action after scalling: 2
#
# The execution price: 1269.0150372210348
#
# Buy Action
#
#
# Target position to buy in money: 499902.39954873995
#
# Actual stock quantity bought: 393.0
#
# The actual money spent to purchase stock: 498722.9096278667
#
# The total fee to be paid 40
# Reward at the step: 0.0003011700882933905
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2)]
#
# The Normalized Money Reserve: 0.0023589798417465065
#
# The Normalized Stock Reserve: 0.997827
#
# The Normalized Net Worth: 1.0001859798417465
#
# The Money Reserve: 1179.4899208732531
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 393.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-06-26 14:20:00 False
# The updated observation at the end of the step:
#  [[ 1.27085000e+03  1.27090000e+03  1.26955000e+03  1.27055000e+03
#    2.52630000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00 -6.55504013e-05]
#  [ 1.26965000e+03  1.27120000e+03  1.26950000e+03  1.26995000e+03
#    2.78500000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00  0.00000000e+00]
#  [ 1.26935000e+03  1.27010000e+03  1.26900000e+03  1.26950000e+03
#    2.24480000e+04  2.35897984e-03  9.97827000e-01  1.00018598e+00
#    0.00000000e+00  3.01170088e-04]]
# {'Time': Timestamp('2023-06-26 14:20:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:20:00')}
#
# Reward at the step: 0.0003011700882933905
#
# Observation at the step: [[ 1.27085000e+03  1.27090000e+03  1.26955000e+03  1.27055000e+03
#    2.52630000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00 -6.55504013e-05]
#  [ 1.26965000e+03  1.27120000e+03  1.26950000e+03  1.26995000e+03
#    2.78500000e+04  9.99884799e-01  0.00000000e+00  9.99884799e-01
#    1.00000000e+00  0.00000000e+00]
#  [ 1.26935000e+03  1.27010000e+03  1.26900000e+03  1.26950000e+03
#    2.24480000e+04  2.35897984e-03  9.97827000e-01  1.00018598e+00
#    0.00000000e+00  3.01170088e-04]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 1269.6884396912444
#
# Hold Action
#
# Reward at the step: 0.00047140118121757587
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0)]
#
# The Normalized Money Reserve: 0.0023589798417465065
#
# The Normalized Stock Reserve: 0.9982985999999999
#
# The Normalized Net Worth: 1.0006575798417465
#
# The Money Reserve: 1179.4899208732531
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 393.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-06-26 14:25:00 False
# The updated observation at the end of the step:
#  [[1.26965000e+03 1.27120000e+03 1.26950000e+03 1.26995000e+03
#   2.78500000e+04 9.99884799e-01 0.00000000e+00 9.99884799e-01
#   1.00000000e+00 0.00000000e+00]
#  [1.26935000e+03 1.27010000e+03 1.26900000e+03 1.26950000e+03
#   2.24480000e+04 2.35897984e-03 9.97827000e-01 1.00018598e+00
#   0.00000000e+00 3.01170088e-04]
#  [1.27000000e+03 1.27020000e+03 1.26925000e+03 1.27010000e+03
#   2.18940000e+04 2.35897984e-03 9.98298600e-01 1.00065758e+00
#   0.00000000e+00 4.71401181e-04]]
# {'Time': Timestamp('2023-06-26 14:25:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:25:00')}
#
# Reward at the step: 0.00047140118121757587
#
# Observation at the step: [[1.26965000e+03 1.27120000e+03 1.26950000e+03 1.26995000e+03
#   2.78500000e+04 9.99884799e-01 0.00000000e+00 9.99884799e-01
#   1.00000000e+00 0.00000000e+00]
#  [1.26935000e+03 1.27010000e+03 1.26900000e+03 1.26950000e+03
#   2.24480000e+04 2.35897984e-03 9.97827000e-01 1.00018598e+00
#   0.00000000e+00 3.01170088e-04]
#  [1.27000000e+03 1.27020000e+03 1.26925000e+03 1.27010000e+03
#   2.18940000e+04 2.35897984e-03 9.98298600e-01 1.00065758e+00
#   0.00000000e+00 4.71401181e-04]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 1270.091954553676
#
# Hold Action
#
# Reward at the step: -7.855143327271023e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0)]
#
# The Normalized Money Reserve: 0.0023589798417465065
#
# The Normalized Stock Reserve: 0.99822
#
# The Normalized Net Worth: 1.0005789798417466
#
# The Money Reserve: 1179.4899208732531
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 393.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-06-26 14:30:00 False
# The updated observation at the end of the step:
#  [[ 1.26935000e+03  1.27010000e+03  1.26900000e+03  1.26950000e+03
#    2.24480000e+04  2.35897984e-03  9.97827000e-01  1.00018598e+00
#    0.00000000e+00  3.01170088e-04]
#  [ 1.27000000e+03  1.27020000e+03  1.26925000e+03  1.27010000e+03
#    2.18940000e+04  2.35897984e-03  9.98298600e-01  1.00065758e+00
#    0.00000000e+00  4.71401181e-04]
#  [ 1.27000000e+03  1.27050000e+03  1.26965000e+03  1.27000000e+03
#    2.38240000e+04  2.35897984e-03  9.98220000e-01  1.00057898e+00
#    0.00000000e+00 -7.85514333e-05]]
# {'Time': Timestamp('2023-06-26 14:30:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:30:00')}
#
# Reward at the step: -7.855143327271023e-05
#
# Observation at the step: [[ 1.26935000e+03  1.27010000e+03  1.26900000e+03  1.26950000e+03
#    2.24480000e+04  2.35897984e-03  9.97827000e-01  1.00018598e+00
#    0.00000000e+00  3.01170088e-04]
#  [ 1.27000000e+03  1.27020000e+03  1.26925000e+03  1.27010000e+03
#    2.18940000e+04  2.35897984e-03  9.98298600e-01  1.00065758e+00
#    0.00000000e+00  4.71401181e-04]
#  [ 1.27000000e+03  1.27050000e+03  1.26965000e+03  1.27000000e+03
#    2.38240000e+04  2.35897984e-03  9.98220000e-01  1.00057898e+00
#    0.00000000e+00 -7.85514333e-05]]
#
# Action taken by the agent: 0
#
# The action, applied to the env by the agent: 0
#
# The actual action after scalling: -2
#
# The execution price: 1269.3821791613448
#
# Sell Action
#
#
# Stock Reserve 393.0
#
# Actual stock quantity to be sold 393
#
# Actual money earned in the stock selling: 498867.1964104085
#
# The total fee to be paid 40
# Reward at the step: -0.0005654397244343809
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2)]
#
# The net Worth at the end of the episode: 500006.68633128173
#
#  The episode length was: 9
# The Normalized Money Reserve: 1.0000133726625635
#
# The Normalized Stock Reserve: 0.0
#
# The Normalized Net Worth: 1.0000133726625635
#
# The Money Reserve: 500006.68633128173
#
# The Effective Money Reserve: 499286.85000000003
#
# The Stock Reserve in Numbers: 0.0
#
# There is no Stock Reserve so Fund_Status is: 1
#
# Time and done status at the end of the step: 2023-06-26 14:35:00 True
# The updated observation at the end of the step:
#  [[ 1.27000000e+03  1.27020000e+03  1.26925000e+03  1.27010000e+03
#    2.18940000e+04  2.35897984e-03  9.98298600e-01  1.00065758e+00
#    0.00000000e+00  4.71401181e-04]
#  [ 1.27000000e+03  1.27050000e+03  1.26965000e+03  1.27000000e+03
#    2.38240000e+04  2.35897984e-03  9.98220000e-01  1.00057898e+00
#    0.00000000e+00 -7.85514333e-05]
#  [ 1.27005000e+03  1.27045000e+03  1.26910000e+03  1.27045000e+03
#    2.94270000e+04  1.00001337e+00  0.00000000e+00  1.00001337e+00
#    1.00000000e+00 -5.65439724e-04]]
# {'Time': Timestamp('2023-06-26 14:35:00')}
#
# Info: {'Time': Timestamp('2023-06-26 14:35:00')}
#
# Reward at the step: -0.0005654397244343809
#
# Observation at the step: [[ 1.27000000e+03  1.27020000e+03  1.26925000e+03  1.27010000e+03
#    2.18940000e+04  2.35897984e-03  9.98298600e-01  1.00065758e+00
#    0.00000000e+00  4.71401181e-04]
#  [ 1.27000000e+03  1.27050000e+03  1.26965000e+03  1.27000000e+03
#    2.38240000e+04  2.35897984e-03  9.98220000e-01  1.00057898e+00
#    0.00000000e+00 -7.85514333e-05]
#  [ 1.27005000e+03  1.27045000e+03  1.26910000e+03  1.27045000e+03
#    2.94270000e+04  1.00001337e+00  0.00000000e+00  1.00001337e+00
#    1.00000000e+00 -5.65439724e-04]]
# Time taken for the episode: 743.691ms
#
# Reseting the Env...
#
# The ramdomly selected stock for the episode: INFY
#
# The dataframe containing historical data of the selected stock:
#                          open     high      low    close  volume
# date
# 2023-06-23 13:15:00  1275.00  1275.40  1274.50  1275.20   64014
# 2023-06-23 13:20:00  1275.20  1275.75  1274.75  1275.20   53502
# 2023-06-23 13:25:00  1275.20  1275.70  1274.35  1274.45   50843
# 2023-06-23 13:30:00  1274.90  1275.00  1274.35  1274.45   44872
# 2023-06-23 13:35:00  1274.45  1275.35  1274.40  1275.00   46606
# ...                      ...      ...      ...      ...     ...
# 2023-08-30 11:55:00  1429.60  1431.00  1429.60  1430.60   44518
# 2023-08-30 12:00:00  1430.60  1431.20  1430.20  1430.70   30206
# ...
#    5.88860000e+04  2.50826027e-01  7.47257600e-01  9.98083627e-01
#    2.00000000e+00 -9.64404319e-04]
#  [ 4.40100000e+02  4.40650000e+02  4.40050000e+02  4.40100000e+02
#    2.23490000e+04  1.25671874e-01  8.71398000e-01  9.97069874e-01
#    2.00000000e+00 -1.01621570e-03]]
#
# Action taken by the agent: 4
#
# The action, applied to the env by the agent: 4
#
# The actual action after scalling: 2
#
# The execution price: 440.06913482632757
#
# Buy Action
#
#
# Target position to buy in money: 62795.937080200885
#
# Actual stock quantity bought: 142.0
#
# The actual money spent to purchase stock: 62489.817145338515
#
# The total fee to be paid 40
# Reward at the step: 4.208814977491816e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(-2), np.int64(-2), np.int64(1), np.int64(-2), np.int64(0), np.int64(2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(-1), np.int64(2), np.int64(-2), np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2)]
#
# The Normalized Money Reserve: 0.0006122398697247409
#
# The Normalized Stock Reserve: 0.9964995999999999
#
# The Normalized Net Worth: 0.9971118398697246
#
# The Money Reserve: 306.1199348623704
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 1132.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-08-18 12:30:00 False
# The updated observation at the end of the step:
#  [[ 4.40400000e+02  4.41250000e+02  4.40150000e+02  4.40600000e+02
#    5.88860000e+04  2.50826027e-01  7.47257600e-01  9.98083627e-01
#    2.00000000e+00 -9.64404319e-04]
#  [ 4.40100000e+02  4.40650000e+02  4.40050000e+02  4.40100000e+02
#    2.23490000e+04  1.25671874e-01  8.71398000e-01  9.97069874e-01
#    2.00000000e+00 -1.01621570e-03]
#  [ 4.40150000e+02  4.40250000e+02  4.39400000e+02  4.40150000e+02
#    1.05113000e+05  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  4.20881498e-05]]
# {'Time': Timestamp('2023-08-18 12:30:00')}
#
# Info: {'Time': Timestamp('2023-08-18 12:30:00')}
#
# Reward at the step: 4.208814977491816e-05
#
# Observation at the step: [[ 4.40400000e+02  4.41250000e+02  4.40150000e+02  4.40600000e+02
#    5.88860000e+04  2.50826027e-01  7.47257600e-01  9.98083627e-01
#    2.00000000e+00 -9.64404319e-04]
#  [ 4.40100000e+02  4.40650000e+02  4.40050000e+02  4.40100000e+02
#    2.23490000e+04  1.25671874e-01  8.71398000e-01  9.97069874e-01
#    2.00000000e+00 -1.01621570e-03]
#  [ 4.40150000e+02  4.40250000e+02  4.39400000e+02  4.40150000e+02
#    1.05113000e+05  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  4.20881498e-05]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 440.5489843955837
#
# Hold Action
#
# Reward at the step: 0.0
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(-2), np.int64(-2), np.int64(1), np.int64(-2), np.int64(0), np.int64(2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(-1), np.int64(2), np.int64(-2), np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0)]
#
# The Normalized Money Reserve: 0.0006122398697247409
#
# The Normalized Stock Reserve: 0.9964995999999999
#
# The Normalized Net Worth: 0.9971118398697246
#
# The Money Reserve: 306.1199348623704
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 1132.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-08-18 12:35:00 False
# The updated observation at the end of the step:
#  [[ 4.40100000e+02  4.40650000e+02  4.40050000e+02  4.40100000e+02
#    2.23490000e+04  1.25671874e-01  8.71398000e-01  9.97069874e-01
#    2.00000000e+00 -1.01621570e-03]
#  [ 4.40150000e+02  4.40250000e+02  4.39400000e+02  4.40150000e+02
#    1.05113000e+05  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  4.20881498e-05]
#  [ 4.40100000e+02  4.40600000e+02  4.39600000e+02  4.40150000e+02
#    3.01140000e+04  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  0.00000000e+00]]
# {'Time': Timestamp('2023-08-18 12:35:00')}
#
# Info: {'Time': Timestamp('2023-08-18 12:35:00')}
#
# Reward at the step: 0.0
#
# Observation at the step: [[ 4.40100000e+02  4.40650000e+02  4.40050000e+02  4.40100000e+02
#    2.23490000e+04  1.25671874e-01  8.71398000e-01  9.97069874e-01
#    2.00000000e+00 -1.01621570e-03]
#  [ 4.40150000e+02  4.40250000e+02  4.39400000e+02  4.40150000e+02
#    1.05113000e+05  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  4.20881498e-05]
#  [ 4.40100000e+02  4.40600000e+02  4.39600000e+02  4.40150000e+02
#    3.01140000e+04  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  0.00000000e+00]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# The execution price: 440.01990211409543
#
# Sell Action
#
#
# Stock Reserve 1132.0
#
# Actual stock quantity to be sold 566
#
# Actual money earned in the stock selling: 249051.26459657802
#
# The total fee to be paid 40
# Reward at the step: 0.0002829063658519631
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(-2), np.int64(-2), np.int64(1), np.int64(-2), np.int64(0), np.int64(2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(-1), np.int64(2), np.int64(-2), np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(-1)]
#
# The Normalized Money Reserve: 0.4986347690628808
#
# The Normalized Stock Reserve: 0.4987592
#
# The Normalized Net Worth: 0.9973939690628808
#
# The Money Reserve: 249317.3845314404
#
# The Effective Money Reserve: 248967.25
#
# The Stock Reserve in Numbers: 566.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-08-18 12:40:00 False
# The updated observation at the end of the step:
#  [[4.40150000e+02 4.40250000e+02 4.39400000e+02 4.40150000e+02
#   1.05113000e+05 6.12239870e-04 9.96499600e-01 9.97111840e-01
#   0.00000000e+00 4.20881498e-05]
#  [4.40100000e+02 4.40600000e+02 4.39600000e+02 4.40150000e+02
#   3.01140000e+04 6.12239870e-04 9.96499600e-01 9.97111840e-01
#   0.00000000e+00 0.00000000e+00]
#  [4.40600000e+02 4.40650000e+02 4.40000000e+02 4.40600000e+02
#   1.77830000e+04 4.98634769e-01 4.98759200e-01 9.97393969e-01
#   2.00000000e+00 2.82906366e-04]]
# {'Time': Timestamp('2023-08-18 12:40:00')}
#
# Info: {'Time': Timestamp('2023-08-18 12:40:00')}
#
# Reward at the step: 0.0002829063658519631
#
# Observation at the step: [[4.40150000e+02 4.40250000e+02 4.39400000e+02 4.40150000e+02
#   1.05113000e+05 6.12239870e-04 9.96499600e-01 9.97111840e-01
#   0.00000000e+00 4.20881498e-05]
#  [4.40100000e+02 4.40600000e+02 4.39600000e+02 4.40150000e+02
#   3.01140000e+04 6.12239870e-04 9.96499600e-01 9.97111840e-01
#   0.00000000e+00 0.00000000e+00]
#  [4.40600000e+02 4.40650000e+02 4.40000000e+02 4.40600000e+02
#   1.77830000e+04 4.98634769e-01 4.98759200e-01 9.97393969e-01
#   2.00000000e+00 2.82906366e-04]]
#
# Action taken by the agent: 1
#
# The action, applied to the env by the agent: 1
#
# The actual action after scalling: -1
#
# The execution price: 440.27439775686815
#
# Sell Action
#
#
# Stock Reserve 566.0
#
# Actual stock quantity to be sold 283
#
# Actual money earned in the stock selling: 124597.65456519369
#
# The total fee to be paid 40
# Reward at the step: -0.00032178107211442965
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(-2), np.int64(-2), np.int64(1), np.int64(-2), np.int64(0), np.int64(2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(-1), np.int64(2), np.int64(-2), np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(-1), np.int64(-1)]
#
# The Normalized Money Reserve: 0.7477500781932681
#
# The Normalized Stock Reserve: 0.249323
#
# The Normalized Net Worth: 0.9970730781932681
#
# The Money Reserve: 373875.0390966341
#
# The Effective Money Reserve: 373713.6
#
# The Stock Reserve in Numbers: 283.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-08-18 12:45:00 False
# The updated observation at the end of the step:
#  [[ 4.40100000e+02  4.40600000e+02  4.39600000e+02  4.40150000e+02
#    3.01140000e+04  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  0.00000000e+00]
#  [ 4.40600000e+02  4.40650000e+02  4.40000000e+02  4.40600000e+02
#    1.77830000e+04  4.98634769e-01  4.98759200e-01  9.97393969e-01
#    2.00000000e+00  2.82906366e-04]
#  [ 4.40500000e+02  4.40700000e+02  4.40000000e+02  4.40500000e+02
#    1.47520000e+04  7.47750078e-01  2.49323000e-01  9.97073078e-01
#    2.00000000e+00 -3.21781072e-04]]
# {'Time': Timestamp('2023-08-18 12:45:00')}
#
# Info: {'Time': Timestamp('2023-08-18 12:45:00')}
#
# Reward at the step: -0.00032178107211442965
#
# Observation at the step: [[ 4.40100000e+02  4.40600000e+02  4.39600000e+02  4.40150000e+02
#    3.01140000e+04  6.12239870e-04  9.96499600e-01  9.97111840e-01
#    0.00000000e+00  0.00000000e+00]
#  [ 4.40600000e+02  4.40650000e+02  4.40000000e+02  4.40600000e+02
#    1.77830000e+04  4.98634769e-01  4.98759200e-01  9.97393969e-01
#    2.00000000e+00  2.82906366e-04]
#  [ 4.40500000e+02  4.40700000e+02  4.40000000e+02  4.40500000e+02
#    1.47520000e+04  7.47750078e-01  2.49323000e-01  9.97073078e-01
#    2.00000000e+00 -3.21781072e-04]]
#
# Action taken by the agent: 2
#
# The action, applied to the env by the agent: 2
#
# The actual action after scalling: 0
#
# The execution price: 440.49442657055096
#
# Hold Action
#
# Reward at the step: -5.67677613414179e-05
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(-2), np.int64(-2), np.int64(1), np.int64(-2), np.int64(0), np.int64(2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(-1), np.int64(2), np.int64(-2), np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(-1), np.int64(-1), np.int64(0)]
#
# The Normalized Money Reserve: 0.7477500781932681
#
# The Normalized Stock Reserve: 0.2492664
#
# The Normalized Net Worth: 0.9970164781932681
#
# The Money Reserve: 373875.0390966341
#
# The Effective Money Reserve: 373628.80000000005
#
# The Stock Reserve in Numbers: 283.0
#
# Both Money and Stock Reserve Exists, so Fund_Status is: 2
#
# Time and done status at the end of the step: 2023-08-18 12:50:00 False
# The updated observation at the end of the step:
#  [[ 4.40600000e+02  4.40650000e+02  4.40000000e+02  4.40600000e+02
#    1.77830000e+04  4.98634769e-01  4.98759200e-01  9.97393969e-01
#    2.00000000e+00  2.82906366e-04]
#  [ 4.40500000e+02  4.40700000e+02  4.40000000e+02  4.40500000e+02
#    1.47520000e+04  7.47750078e-01  2.49323000e-01  9.97073078e-01
#    2.00000000e+00 -3.21781072e-04]
#  [ 4.40400000e+02  4.40600000e+02  4.40100000e+02  4.40400000e+02
#    1.26380000e+04  7.47750078e-01  2.49266400e-01  9.97016478e-01
#    2.00000000e+00 -5.67677613e-05]]
# {'Time': Timestamp('2023-08-18 12:50:00')}
#
# Info: {'Time': Timestamp('2023-08-18 12:50:00')}
#
# Reward at the step: -5.67677613414179e-05
#
# Observation at the step: [[ 4.40600000e+02  4.40650000e+02  4.40000000e+02  4.40600000e+02
#    1.77830000e+04  4.98634769e-01  4.98759200e-01  9.97393969e-01
#    2.00000000e+00  2.82906366e-04]
#  [ 4.40500000e+02  4.40700000e+02  4.40000000e+02  4.40500000e+02
#    1.47520000e+04  7.47750078e-01  2.49323000e-01  9.97073078e-01
#    2.00000000e+00 -3.21781072e-04]
#  [ 4.40400000e+02  4.40600000e+02  4.40100000e+02  4.40400000e+02
#    1.26380000e+04  7.47750078e-01  2.49266400e-01  9.97016478e-01
#    2.00000000e+00 -5.67677613e-05]]
#
# Action taken by the agent: 4
#
# The action, applied to the env by the agent: 4
#
# The actual action after scalling: 2
#
# The execution price: 440.11188333610517
#
# Buy Action
#
#
# Target position to buy in money: 373835.0390966341
#
# Actual stock quantity bought: 849.0
#
# The actual money spent to purchase stock: 373654.9889523533
#
# The total fee to be paid 40
# Reward at the step: -0.00015725941933774552
# The appended action list: [np.int64(0), np.int64(-2), np.int64(0), np.int64(-1), np.int64(2), np.int64(0), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(-1), np.int64(-2), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(-2), np.int64(1), np.int64(-2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(1), np.int64(1), np.int64(-2), np.int64(-2), np.int64(1), np.int64(-2), np.int64(0), np.int64(2), np.int64(-1), np.int64(-1), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(-1), np.int64(2), np.int64(-2), np.int64(-1), np.int64(1), np.int64(0), np.int64(1), np.int64(1), np.int64(2), np.int64(0), np.int64(-1), np.int64(-1), np.int64(0), np.int64(2)]
#
# The net Worth at the end of the episode: 498429.85014428076
#
#  The episode length was: 9
# The Normalized Money Reserve: 0.0003601002885615453
#
# The Normalized Stock Reserve: 0.9964995999999999
#
# The Normalized Net Worth: 0.9968597002885615
#
# The Money Reserve: 180.05014428077266
#
# The Effective Money Reserve: 0.0
#
# The Stock Reserve in Numbers: 1132.0
#
# There is no Money Reserve so Fund_Status is: 0
#
# Time and done status at the end of the step: 2023-08-18 12:55:00 True
# The updated observation at the end of the step:
#  [[ 4.40500000e+02  4.40700000e+02  4.40000000e+02  4.40500000e+02
#    1.47520000e+04  7.47750078e-01  2.49323000e-01  9.97073078e-01
#    2.00000000e+00 -3.21781072e-04]
#  [ 4.40400000e+02  4.40600000e+02  4.40100000e+02  4.40400000e+02
#    1.26380000e+04  7.47750078e-01  2.49266400e-01  9.97016478e-01
#    2.00000000e+00 -5.67677613e-05]
#  [ 4.40150000e+02  4.40700000e+02  4.40100000e+02  4.40150000e+02
#    1.38530000e+04  3.60100289e-04  9.96499600e-01  9.96859700e-01
#    0.00000000e+00 -1.57259419e-04]]
# {'Time': Timestamp('2023-08-18 12:55:00')}
#
# Info: {'Time': Timestamp('2023-08-18 12:55:00')}
#
# Reward at the step: -0.00015725941933774552
#
# Observation at the step: [[ 4.40500000e+02  4.40700000e+02  4.40000000e+02  4.40500000e+02
#    1.47520000e+04  7.47750078e-01  2.49323000e-01  9.97073078e-01
#    2.00000000e+00 -3.21781072e-04]
#  [ 4.40400000e+02  4.40600000e+02  4.40100000e+02  4.40400000e+02
#    1.26380000e+04  7.47750078e-01  2.49266400e-01  9.97016478e-01
#    2.00000000e+00 -5.67677613e-05]
#  [ 4.40150000e+02  4.40700000e+02  4.40100000e+02  4.40150000e+02
#    1.38530000e+04  3.60100289e-04  9.96499600e-01  9.96859700e-01
#    0.00000000e+00 -1.57259419e-04]]
# Time taken for the episode: 524.145ms
